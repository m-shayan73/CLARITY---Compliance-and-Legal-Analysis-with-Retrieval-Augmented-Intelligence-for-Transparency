# %%
# Install required packages
# !pip install -q llama-index llama-index-packs-raptor llama-index-vector-stores-chroma nest-asyncio pyyaml chromadb
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 628.3/628.3 kB 20.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 66.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.6/278.6 kB 18.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 63.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 58.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 52.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 88.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.6/166.6 kB 11.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.1/118.1 kB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.8/88.8 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.1/442.1 kB 27.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.8/195.8 kB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.3/390.3 kB 25.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 19.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 20.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 52.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 80.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.8/443.8 kB 28.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.6 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.17.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.29.1 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 5.29.1 which is incompatible.

# %%
# !pip install tenacity
# Out:
# Requirement already satisfied: tenacity in /usr/local/lib/python3.10/dist-packages (8.5.0)

# %%
import yaml
import os
import logging
from typing import Dict, Any

# Setup logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

def load_config(config_path: str = 'config.yaml') -> Dict[str, Any]:
    """Load configuration from YAML file."""
    try:
        with open(config_path, 'r') as file:
            config = yaml.safe_load(file)
        return config
    except FileNotFoundError:
        logger.error(f"Configuration file not found: {config_path}")
        raise
    except yaml.YAMLError as e:
        logger.error(f"Error parsing YAML configuration: {e}")
        raise

# Define configuration directly in the notebook
config = {
    "openai_api_key": os.getenv("OPENAI_API_KEY"),
    "models": {
        "embedding": "text-embedding-3-small",
        "llm": "gpt-4o-mini"
    },
    "chunk_size": 400,
    "chunk_overlap": 50,
    "similarity_top_k": 2,
    "mode": "tree_traversal",
    "temperature": 0
}

# Set OpenAI API key
os.environ["OPENAI_API_KEY"] = config['openai_api_key']

# %%
# Download the RAPTOR paper
# !wget -q https://moitt.gov.pk/SiteImage/Misc/files/Final%20Draft%20Personal%20Data%20Protection%20Bill%20May%202023.pdf -O ./DataLaw2.pdf
logger.info("RAPTOR paper downloaded successfully.")

# %%
import nest_asyncio
from llama_index.core import SimpleDirectoryReader
from llama_index.vector_stores.chroma import ChromaVectorStore
import chromadb

# Apply nest_asyncio to allow asynchronous operations in Jupyter notebooks
nest_asyncio.apply()

def load_document(file_path: str):
    """Load document from file."""
    documents = SimpleDirectoryReader(input_files=[file_path]).load_data()
    logger.info(f"Document loaded successfully: {file_path}")
    return documents

def setup_vector_store(db_path: str, collection_name: str):
    """Set up ChromaDB vector store."""
    client = chromadb.PersistentClient(path=db_path)
    collection = client.get_or_create_collection(collection_name)
    vector_store = ChromaVectorStore(chroma_collection=collection)
    logger.info(f"Vector store set up successfully: {collection_name}")
    return vector_store

# Load document
documents = load_document("./DataLaw2.pdf")

# Setup vector store
vector_store = setup_vector_store("./DataLaw2_db", "raptor")

# %%
from llama_index.core.node_parser import SentenceSplitter
from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.packs.raptor import RaptorPack
from tenacity import retry, wait_exponential, stop_after_attempt

# Add retry decorator to OpenAIEmbedding
@retry(wait=wait_exponential(multiplier=1, min=1, max=10), stop=stop_after_attempt(6))
async def _aget_text_embedding_with_retry(self, text: str):
    """Get text embedding for a single text."""
    return await self._aget_text_embeddings([text])[0]

# Monkey patch the original method
OpenAIEmbedding._aget_text_embedding = _aget_text_embedding_with_retry


def create_raptor_pack(documents, vector_store, config):
    """Create and configure RAPTOR pack."""
    pack = RaptorPack(
        documents,
        embed_model=OpenAIEmbedding(model=config['models']['embedding']),
        llm=OpenAI(model=config['models']['llm'], temperature=config['temperature']),
        vector_store=vector_store,
        similarity_top_k=config['similarity_top_k'],
        mode=config['mode'],
        transformations=[SentenceSplitter(chunk_size=config['chunk_size'], chunk_overlap=config['chunk_overlap'])],
    )
    logger.info("RAPTOR pack created successfully.")
    return pack

# Create RAPTOR pack
raptor_pack = create_raptor_pack(documents, vector_store, config)
# Out:
# Generating embeddings for level 0.
# Performing clustering for level 0.
# Generating summaries for level 0 with 15 clusters.
# Level 0 created summaries/clusters: 15
# Generating embeddings for level 1.
# Performing clustering for level 1.
# Generating summaries for level 1 with 3 clusters.
# Level 1 created summaries/clusters: 3
# Generating embeddings for level 2.
# Performing clustering for level 2.
# Generating summaries for level 2 with 1 clusters.
# Level 2 created summaries/clusters: 1

# %% [markdown]
# ### Notes:
# - Replace `your_api_key_here` with your OpenAI API key.
# - The RAPTOR paper is downloaded and stored locally in the notebook.
# - The script initializes and sets up the RAPTOR pack using the `llama-index` library.

# %%
from llama_index.packs.raptor import RaptorRetriever
from llama_index.core.query_engine import RetrieverQueryEngine
from typing import List, Tuple

def create_raptor_retriever(vector_store, config):
    """Create RAPTOR retriever."""
    retriever = RaptorRetriever(
        [],
        embed_model=OpenAIEmbedding(model=config['models']['embedding']),
        llm=OpenAI(model=config['models']['llm'], temperature=config['temperature']),
        vector_store=vector_store,
        similarity_top_k=config['similarity_top_k'],
        mode=config['mode'],
    )
    logger.info("RAPTOR retriever created successfully.")
    return retriever

def create_query_engine(retriever, config):
    """Create query engine."""
    query_engine = RetrieverQueryEngine.from_args(
        retriever,
        llm=OpenAI(model=config['models']['llm'], temperature=config['temperature'])
    )
    logger.info("Query engine created successfully.")
    return query_engine

def run_multiple_queries(query_engine, queries: List[str]) -> List[Tuple[str, str]]:
    """Run multiple queries and return results."""
    results = []
    for query in queries:
        response = query_engine.query(query)
        results.append((query, str(response)))
        logger.info(f"Query processed successfully: {query}")
    return results

# Create retriever and query engine
retriever = create_raptor_retriever(vector_store, config)
query_engine = create_query_engine(retriever, config)

# %%
# Example usage
queries = [
    """
    Extract and list the compliance points that an application's privacy policy should address according to the Pakistan Data Protection Law. Focus on identifying distinct categories or principles. list these compliance points in terms of priority and importance.

    Provide the results in the following structured format:
    - [Category Name 1]: Brief explanation of the principle.
    - [Category Name 2]: Brief explanation of the principle.
    - [Category Name 3]: Brief explanation of the principle.

    Ensure the categories are clearly defined and separate, so they can be used for follow-up queries.
    """
]

results = run_multiple_queries(query_engine, queries)

# Process results to generate follow-up prompts
follow_up_prompts = []

for query, response in results:
    print(f"Query: {query}")
    print(f"Response: {response}")
    print("-" * 50)

    # Extract categories dynamically based on the expected structured format
    categories = []
    for line in response.splitlines():
        if line.startswith("- "):  # Match the expected structure of categories
            category = line.split(":", 1)[0].strip("- ").strip()
            categories.append(category)

    # Generate follow-up prompts for each extracted category
    for category in categories:
        follow_up_prompts.append(
            f"""
            Retrieve the exact legal requirements for '{category}' as outlined in the Pakistan Data Protection Law.
            Provide specific details, including definitions, obligations, and any associated penalties or compliance measures.
            """
        )

# Print the follow-up prompts
for i, prompt in enumerate(follow_up_prompts, start=1):
    print(f"Follow-up Prompt {i}:")
    print(prompt.strip())
    print("-" * 50)
# Out:
# Query:
#     Extract and list the compliance points that an application's privacy policy should address according to the Pakistan Data Protection Law. Focus on identifying distinct categories or principles. list these compliance points in terms of priority and importance.
#
#     Provide the results in the following structured format:
#     - [Category Name 1]: Brief explanation of the principle.
#     - [Category Name 2]: Brief explanation of the principle.
#     - [Category Name 3]: Brief explanation of the principle.
#
#     Ensure the categories are clearly defined and separate, so they can be used for follow-up queries.
#
# Response: - **Personal Data Collection and Use**: The application must inform data subjects at the time of data collection about the purpose for which their personal data is being collected and ensure that it is not used for any other purpose without consent.
#
# - **Consent for Disclosure**: Personal data should not be disclosed without the explicit consent of the data subject, except for purposes directly related to the original purpose of collection or as specified by law.
#
# - **Data Breach Notification**: In the event of a personal data breach, the application must notify the relevant authorities and affected data subjects within 72 hours, providing details about the breach, its consequences, and measures taken to address it.
#
# - **Security Requirements**: The application must implement best international standards to protect personal data from loss, misuse, unauthorized access, and other risks.
#
# - **Record Keeping of Data Breaches**: The application should maintain a record of all personal data breaches, including details of the breach, its effects, and remedial actions taken.
#
# - **Language Accessibility**: Notices regarding data collection and processing must be provided in a language that is clear and accessible to the data subject, allowing them to choose their preferred language.
# --------------------------------------------------
# Follow-up Prompt 1:
# Retrieve the exact legal requirements for '**Personal Data Collection and Use**' as outlined in the Pakistan Data Protection Law.
#             Provide specific details, including definitions, obligations, and any associated penalties or compliance measures.
# --------------------------------------------------
# Follow-up Prompt 2:
# Retrieve the exact legal requirements for '**Consent for Disclosure**' as outlined in the Pakistan Data Protection Law.
#             Provide specific details, including definitions, obligations, and any associated penalties or compliance measures.
# --------------------------------------------------
# Follow-up Prompt 3:
# Retrieve the exact legal requirements for '**Data Breach Notification**' as outlined in the Pakistan Data Protection Law.
#             Provide specific details, including definitions, obligations, and any associated penalties or compliance measures.
# --------------------------------------------------
# Follow-up Prompt 4:
# Retrieve the exact legal requirements for '**Security Requirements**' as outlined in the Pakistan Data Protection Law.
#             Provide specific details, including definitions, obligations, and any associated penalties or compliance measures.
# --------------------------------------------------
# Follow-up Prompt 5:
# Retrieve the exact legal requirements for '**Record Keeping of Data Breaches**' as outlined in the Pakistan Data Protection Law.
#             Provide specific details, including definitions, obligations, and any associated penalties or compliance measures.
# --------------------------------------------------
# Follow-up Prompt 6:
# Retrieve the exact legal requirements for '**Language Accessibility**' as outlined in the Pakistan Data Protection Law.
#             Provide specific details, including definitions, obligations, and any associated penalties or compliance measures.
# --------------------------------------------------

# %%
results = run_multiple_queries(query_engine, follow_up_prompts)

# Print results
for query, response in results:
    print(f"Query: {query}")
    print(f"Response: {response}")
    print("-" * 50)
# Out:
# Query:
#             Retrieve the exact legal requirements for '**Personal Data Collection and Use**' as outlined in the Pakistan Data Protection Law.
#             Provide specific details, including definitions, obligations, and any associated penalties or compliance measures.
#
# Response: The legal requirements for personal data collection and use as outlined in the Pakistan Data Protection Law include the following key points:
#
# 1. **Grounds for Processing Personal Data**:
#    - Personal data must be collected, processed, and disclosed lawfully and fairly, in compliance with the provisions of the Act.
#    - Data collection must be for specified, explicit, and legitimate purposes, and further processing must not be incompatible with these purposes. The data collected should be adequate, relevant, and limited to the purposes for which it is processed.
#
# 2. **Registration Obligations**:
#    - Data controllers and data processors operating within Pakistan must register with the Commission in a manner specified by the registration framework. If they are already registered with a public body, they only need to inform the Commission.
#
# 3. **Definition of Significant Data Controllers/Processors**:
#    - A "significant" data controller or processor is defined as one that is sufficiently important based on factors such as sales revenue, profit, number of employees, market share, capital employed, number of users, or type of data collected.
#
# 4. **Scope and Applicability**:
#    - The Act applies to any data controller or processor that processes or controls personal data and is established or registered within Pakistan. It also applies to those incorporated outside Pakistan but conducting activities related to personal data within the territory.
#
# 5. **Third Party Definition**:
#    - A "third party" is defined as any person other than the data subject, relevant persons concerning the data subject, data controllers, data processors, or individuals authorized in writing by the data controller to process personal data.
#
# 6. **Sensitive Personal Data Sharing**:
#    - The Commission is tasked with devising a mechanism for sharing sensitive personal data with the government, provided it relates to public order or national security and complies with applicable law.
#
# 7. **Compliance Measures**:
#    - The Commission will recommend measures to ensure consistency and enforcement of personal data protection policies across Pakistan and suggest compliance with international standards.
#
# While specific penalties for non-compliance are not detailed in the provided information, the obligations outlined indicate a framework for lawful data processing and the importance of registration and adherence to defined purposes for data collection.
# --------------------------------------------------
# Query:
#             Retrieve the exact legal requirements for '**Consent for Disclosure**' as outlined in the Pakistan Data Protection Law.
#             Provide specific details, including definitions, obligations, and any associated penalties or compliance measures.
#
# Response: The legal requirements for **Consent for Disclosure** as outlined in the Pakistan Data Protection Law include the following:
#
# 1. **Consent Definition**: Consent is defined as any freely given, specific, informed, and unambiguous indication of the data subject’s intention, signified by a statement or clear affirmative action, agreeing to the collecting, obtaining, and processing of personal data.
#
# 2. **Disclosure Conditions**: Personal data may be disclosed by a data controller for purposes other than those stated at the time of collection under specific circumstances:
#    - The data subject has given consent to the disclosure.
#    - The disclosure is necessary for preventing or detecting a crime, or for investigations.
#    - The disclosure is required or authorized by law or by a court order.
#    - The data controller reasonably believes they have the right to disclose the personal data.
#    - The data controller reasonably believes they had the consent of the data subject if the data subject had known about the disclosure and its circumstances.
#    - The disclosure is justified in the public interest as determined by the Commission in advance.
#
# 3. **Withdrawal of Consent**: A data subject has the right to withdraw consent at any time through a written notice. Upon receiving this notice, the data controller must cease processing the personal data. The withdrawal does not affect the lawfulness of processing based on consent prior to its withdrawal.
#
# 4. **Penalties for Non-compliance**: If a data controller fails to comply with the requirement to cease processing upon withdrawal of consent, it is considered an offence, punishable by a fine not exceeding 50,000 USD or an equivalent amount in Pakistani Rupees.
#
# These provisions ensure that the data subject's rights are protected and that any disclosure of personal data is conducted in compliance with the law.
# --------------------------------------------------
# Query:
#             Retrieve the exact legal requirements for '**Data Breach Notification**' as outlined in the Pakistan Data Protection Law.
#             Provide specific details, including definitions, obligations, and any associated penalties or compliance measures.
#
# Response: The legal requirements for Data Breach Notification as outlined in the Pakistan Data Protection Law include the following obligations for the data controller:
#
# 1. **Notification Timeline**: In the event of a personal data breach, the data controller must notify the Commission and the data subject without undue delay, and where reasonably possible, not beyond 72 hours of becoming aware of the breach. If the breach is unlikely to result in the infringement of rights and freedoms of the data subject, notification may not be required.
#
# 2. **Delay in Notification**: If there is a delay in notifying the personal data breach beyond the 72-hour window, the data controller must provide a valid reason for the delay when furnishing the notification.
#
# 3. **Content of Notification**: The personal data breach notification must include at least the following information:
#    - A description of the nature of the personal data breach, including the categories and approximate number of data subjects concerned, as well as the categories and approximate number of concerned personal data records.
#    - The name and contact details of the data protection officer or another point of contact for additional information.
#    - The likely consequences of the personal data breach.
#    - Measures adopted or proposed by the data controller to address the personal data breach, including measures to mitigate its possible adverse effects.
#
# 4. **Record Keeping**: The data controller is required to maintain a record of all personal data breaches, which should include the facts concerning the breaches, their effects, and the remedial actions taken.
#
# These requirements ensure that data subjects are informed of breaches that may affect their rights and freedoms, and that data controllers are held accountable for managing personal data responsibly.
# --------------------------------------------------
# Query:
#             Retrieve the exact legal requirements for '**Security Requirements**' as outlined in the Pakistan Data Protection Law.
#             Provide specific details, including definitions, obligations, and any associated penalties or compliance measures.
#
# Response: The legal requirements for "Security Requirements" as outlined in the Pakistan Data Protection Law include the following:
#
# 1. **Security Standards**: The Commission is tasked with prescribing the best international standards to protect personal data. This is aimed at safeguarding personal data from various risks, including:
#    - Loss
#    - Misuse
#    - Modification
#    - Unauthorized or accidental access
#    - Disclosure
#    - Alteration
#    - Destruction
#
# 2. **Obligations**: Data controllers and processors are required to implement these prescribed security measures to ensure the protection of personal data.
#
# 3. **Compliance Measures**: The Commission will recommend steps to the Federal Government, Provincial Governments, Local Governments, and relevant entities to ensure consistency and enforcement of personal data protection policies across Pakistan. This includes suggesting measures to align Pakistan’s data protection laws with international standards.
#
# 4. **Sensitive Data Sharing**: There is a provision for sharing sensitive personal data with the government of Pakistan, provided that the data pertains to public order or national security and is required within the parameters of applicable law.
#
# Specific penalties or detailed compliance measures are not explicitly mentioned in the provided context.
# --------------------------------------------------
# Query:
#             Retrieve the exact legal requirements for '**Record Keeping of Data Breaches**' as outlined in the Pakistan Data Protection Law.
#             Provide specific details, including definitions, obligations, and any associated penalties or compliance measures.
#
# Response: The legal requirements for record keeping of data breaches as outlined in the Pakistan Data Protection Law include the following obligations for the data controller:
#
# 1. **Record Maintenance**: The data controller is required to maintain a record of all personal data breaches. This record must include:
#    - Facts concerning the personal data breaches.
#    - Their effects.
#    - The remedial action taken in response to the breaches.
#
# 2. **Notification**: In the event of a personal data breach, the data controller must notify the Commission and the affected data subjects without undue delay, and within 72 hours of becoming aware of the breach, unless the breach is unlikely to result in an infringement of the rights and freedoms of the data subject.
#
# 3. **Delay in Notification**: If there is a delay in notifying the breach beyond the 72-hour window, the data controller must provide a valid reason for the delay when notifying the Commission and the data subjects.
#
# 4. **Content of Notification**: The notification of a personal data breach must include:
#    - A description of the nature of the breach, including categories and approximate number of data subjects and personal data records involved.
#    - Contact details of the data protection officer or another point of contact for additional information.
#    - Likely consequences of the breach.
#    - Measures adopted or proposed to address the breach, including any measures to mitigate its possible adverse effects.
#
# These requirements ensure that data controllers are accountable for breaches and that there is transparency regarding the handling of personal data. Compliance with these obligations is essential for protecting the rights and freedoms of data subjects.
# --------------------------------------------------
# Query:
#             Retrieve the exact legal requirements for '**Language Accessibility**' as outlined in the Pakistan Data Protection Law.
#             Provide specific details, including definitions, obligations, and any associated penalties or compliance measures.
#
# Response: The legal requirements for language accessibility as outlined in the Pakistan Data Protection Law specify that a notice must be served in English or any other language as specified in Article 251 of the Constitution of the Islamic Republic of Pakistan, 1973. Additionally, individuals must be provided with a clear and readily accessible means to choose their preferred language.
#
# While the context does not detail specific penalties or compliance measures related to language accessibility, it emphasizes the obligation of data controllers to ensure that individuals can understand the information provided to them in a language of their choice.
# --------------------------------------------------

# %%
# Step 1: Collect all responses into a single report prompt
report_prompt = """
Using the following compliance details, generate a comprehensive report in the form of a questionnaire.
The report should include sections for each compliance category, with a list of detailed questions based on the provided responses.

Structure:
- Section Title: <Compliance Category Name>
- Brief Description: A short summary of the category based on the response.
- Questions:
  - A list of questions based on the detailed information in the response.

Responses:
"""

for query, response in results:
    report_prompt += f"""
Query: {query.strip()}
Response: {response.strip()}
"""
report_prompt += "\n"

# Step 2: Add final instructions for the LLM to structure the report
report_prompt += """
Ensure the generated report is clearly formatted and suitable for presenting to a privacy policy agent. Each section should be titled with the compliance category and should include a concise summary and a detailed list of questions.
"""

# Step 3: Pass the prompt to the LLM
llm_generated_report = query_engine.query(report_prompt)

# Step 4: Print the generated report
print("\nGenerated Report Questionnaire:")
print(llm_generated_report)
# Out:
# Generated Report Questionnaire:
# # Compliance Report Questionnaire
#
# ## Section Title: Personal Data Collection and Use
# ### Brief Description:
# This section outlines the legal requirements for the lawful and fair collection, processing, and disclosure of personal data, emphasizing the need for specified purposes and registration obligations for data controllers and processors.
#
# ### Questions:
# 1. What are the specified, explicit, and legitimate purposes for which personal data is collected?
# 2. How does the data controller ensure that the data collected is adequate, relevant, and limited to these purposes?
# 3. What is the process for registering with the Commission, and what information is required?
# 4. How is a "significant" data controller or processor defined, and what criteria are used to determine this status?
# 5. What measures are in place to ensure compliance with the Act for data controllers or processors operating outside Pakistan?
#
# ---
#
# ## Section Title: Consent for Disclosure
# ### Brief Description:
# This section details the requirements for obtaining consent from data subjects before disclosing their personal data, including conditions for disclosure and the rights of data subjects regarding their consent.
#
# ### Questions:
# 1. How is consent defined in the context of personal data disclosure?
# 2. Under what circumstances can personal data be disclosed without the data subject's consent?
# 3. What process must a data subject follow to withdraw their consent, and how is this communicated to the data controller?
# 4. What penalties are imposed for failing to cease processing upon withdrawal of consent?
#
# ---
#
# ## Section Title: Data Breach Notification
# ### Brief Description:
# This section outlines the obligations of data controllers in the event of a personal data breach, including notification timelines and the required content of breach notifications.
#
# ### Questions:
# 1. What is the timeline for notifying the Commission and data subjects in the event of a data breach?
# 2. What information must be included in the notification of a personal data breach?
# 3. What are the conditions under which notification may not be required?
# 4. How does the data controller document and justify any delays in notification?
#
# ---
#
# ## Section Title: Security Requirements
# ### Brief Description:
# This section specifies the security measures that data controllers and processors must implement to protect personal data from various risks, as prescribed by the Commission.
#
# ### Questions:
# 1. What international security standards are recommended by the Commission for protecting personal data?
# 2. What specific security measures must data controllers and processors implement?
# 3. How does the Commission ensure consistency and enforcement of these security measures across different levels of government?
# 4. What provisions exist for sharing sensitive personal data with the government?
#
# ---
#
# ## Section Title: Record Keeping of Data Breaches
# ### Brief Description:
# This section mandates the maintenance of records related to personal data breaches, detailing the information that must be documented and the notification process.
#
# ### Questions:
# 1. What specific information must be included in the records of personal data breaches?
# 2. How does the data controller ensure timely notification of breaches to the Commission and affected data subjects?
# 3. What are the requirements for documenting the reasons for any delays in breach notifications?
# 4. How does the data controller address the potential consequences of a data breach in their records?
#
# ---
#
# ## Section Title: Language Accessibility
# ### Brief Description:
# This section emphasizes the importance of providing notices in accessible languages to ensure that data subjects can understand the information regarding their personal data.
#
# ### Questions:
# 1. In which languages must notices be served according to the law?
# 2. What mechanisms are in place to allow individuals to choose their preferred language for communication?
# 3. How does the data controller ensure that language accessibility is maintained in their privacy policies?
# 4. Are there any specific compliance measures or penalties related to language accessibility that data controllers should be aware of?

# %%
# prompt: save the generate llm_generated_report into text

# Step 4: Save the generated report to a text file
with open("llm_generated_report.txt", "w") as file:
    file.write(str(llm_generated_report))

# %%
# # Step 1: Read Questions from the Text File
# questions_file_path = "llm_generated_report.txt"

# with open(questions_file_path, "r") as file:
#     questions = file.readlines()

# # Step 2: Prepare Questions for Querying RAG
# # Clean and filter out any empty lines or unnecessary content
# questions = [q.strip() for q in questions if q.strip()]  # Remove blank lines and strip whitespace

# # Debug: Print the list of questions to ensure correctness
# print("\nQuestions to be Queried:")
# for i, question in enumerate(questions, start=1):
#     print(f"{i}. {question}")
# print("-" * 50)

# # Step 3: Query Each Question Using Raptor RAG
# responses = []
# for question in questions:
#     response = query_engine.query(question)  # Query the question against the RAG system
#     responses.append((question, response.text.strip()))  # Collect the question and response

# # Step 4: Print the Results
# print("\nResults from Raptor RAG:")
# for i, (question, response) in enumerate(responses, start=1):
#     print(f"Question {i}: {question}")
#     print(f"Response {i}: {response}")
#     print("=" * 50)

# # Step 5: Save the Results to a Text File
# output_file_path = "data_protection_requirements.txt"

# with open(output_file_path, "w") as file:
#     for question, response in responses:
#         file.write(f"Question: {question}\n")
#         file.write(f"Response: {response}\n")
#         file.write("=" * 50 + "\n")

# print(f"\nResults have been saved to: {output_file_path}")

# %%
# Step 1: Read Questions from the Text File
questions_file_path = "llm_generated_report.txt"

with open(questions_file_path, "r") as file:
    questions = file.readlines()

# Step 2: Prepare Questions for Querying RAG
# Clean and filter out any empty lines or unnecessary content
questions = [q.strip() for q in questions if q.strip()]  # Remove blank lines and strip whitespace

# Debug: Print the list of questions to ensure correctness
print("\nQuestions to be Queried:")
for i, question in enumerate(questions, start=1):
    print(f"{i}. {question}")
print("-" * 50)

# Step 3: Query Each Question Using Raptor RAG
responses = []
for question in questions:
    response = query_engine.query(question)  # Query the question against the RAG system
    # Access the response content using the 'response' attribute instead of 'text'
    responses.append((question, response.response.strip()))  # Collect the question and response

# Step 4: Print the Results
print("\nResults from Raptor RAG:")
for i, (question, response) in enumerate(responses, start=1):
    print(f"Question {i}: {question}")
    print(f"Response {i}: {response}")
    print("=" * 50)

# Step 5: Save the Results to a Text File
output_file_path = "data_protection_requirements.txt"

with open(output_file_path, "w") as file:
    for question, response in responses:
        file.write(f"Question: {question}\n")
        file.write(f"Response: {response}\n")
        file.write("=" * 50 + "\n")

print(f"\nResults have been saved to: {output_file_path}")
# Out:
# Questions to be Queried:
# 1. # Compliance Report Questionnaire
# 2. ## Section Title: Personal Data Collection and Use
# 3. ### Brief Description:
# 4. This section outlines the legal requirements for the lawful and fair collection, processing, and disclosure of personal data, emphasizing the need for specified purposes and registration obligations for data controllers and processors.
# 5. ### Questions:
# 6. 1. What are the specified, explicit, and legitimate purposes for which personal data is collected?
# 7. 2. How does the data controller ensure that the data collected is adequate, relevant, and limited to these purposes?
# 8. 3. What is the process for registering with the Commission, and what information is required?
# 9. 4. How is a "significant" data controller or processor defined, and what criteria are used to determine this status?
# 10. 5. What measures are in place to ensure compliance with the Act for data controllers or processors operating outside Pakistan?
# 11. ---
# 12. ## Section Title: Consent for Disclosure
# 13. ### Brief Description:
# 14. This section details the requirements for obtaining consent from data subjects before disclosing their personal data, including conditions for disclosure and the rights of data subjects regarding their consent.
# 15. ### Questions:
# 16. 1. How is consent defined in the context of personal data disclosure?
# 17. 2. Under what circumstances can personal data be disclosed without the data subject's consent?
# 18. 3. What process must a data subject follow to withdraw their consent, and how is this communicated to the data controller?
# 19. 4. What penalties are imposed for failing to cease processing upon withdrawal of consent?
# 20. ---
# 21. ## Section Title: Data Breach Notification
# 22. ### Brief Description:
# 23. This section outlines the obligations of data controllers in the event of a personal data breach, including notification timelines and the required content of breach notifications.
# 24. ### Questions:
# 25. 1. What is the timeline for notifying the Commission and data subjects in the event of a data breach?
# 26. 2. What information must be included in the notification of a personal data breach?
# 27. 3. What are the conditions under which notification may not be required?
# 28. 4. How does the data controller document and justify any delays in notification?
# 29. ---
# 30. ## Section Title: Security Requirements
# 31. ### Brief Description:
# 32. This section specifies the security measures that data controllers and processors must implement to protect personal data from various risks, as prescribed by the Commission.
# 33. ### Questions:
# 34. 1. What international security standards are recommended by the Commission for protecting personal data?
# 35. 2. What specific security measures must data controllers and processors implement?
# 36. 3. How does the Commission ensure consistency and enforcement of these security measures across different levels of government?
# 37. 4. What provisions exist for sharing sensitive personal data with the government?
# 38. ---
# 39. ## Section Title: Record Keeping of Data Breaches
# 40. ### Brief Description:
# 41. This section mandates the maintenance of records related to personal data breaches, detailing the information that must be documented and the notification process.
# 42. ### Questions:
# 43. 1. What specific information must be included in the records of personal data breaches?
# 44. 2. How does the data controller ensure timely notification of breaches to the Commission and affected data subjects?
# 45. 3. What are the requirements for documenting the reasons for any delays in breach notifications?
# 46. 4. How does the data controller address the potential consequences of a data breach in their records?
# 47. ---
# 48. ## Section Title: Language Accessibility
# 49. ### Brief Description:
# 50. This section emphasizes the importance of providing notices in accessible languages to ensure that data subjects can understand the information regarding their personal data.
# 51. ### Questions:
# 52. 1. In which languages must notices be served according to the law?
# 53. 2. What mechanisms are in place to allow individuals to choose their preferred language for communication?
# 54. 3. How does the data controller ensure that language accessibility is maintained in their privacy policies?
# 55. 4. Are there any specific compliance measures or penalties related to language accessibility that data controllers should be aware of?
# --------------------------------------------------
#
# Results from Raptor RAG:
# Question 1: # Compliance Report Questionnaire
# Response 1: A compliance report questionnaire typically includes sections that assess adherence to data protection regulations, including the handling of personal data, response to data correction requests, and the management of complaints regarding data processing. It may cover areas such as:
#
# 1. **Data Correction Requests**: Procedures for addressing requests for data corrections, including timelines and communication with requestors.
# 2. **Complaint Handling**: Mechanisms for receiving and processing complaints related to data protection violations, including documentation and follow-up actions.
# 3. **Consent Management**: Processes for obtaining, managing, and withdrawing consent from data subjects.
# 4. **Breach Notifications**: Protocols for notifying relevant parties in the event of data breaches or violations.
# 5. **Training and Awareness**: Evaluation of staff training on data protection policies and compliance requirements.
#
# The questionnaire should also include questions about the effectiveness of these processes and any areas for improvement.
# ==================================================
# Question 2: ## Section Title: Personal Data Collection and Use
# Response 2: The section on Personal Data Collection and Use outlines the requirements and conditions under which personal data can be collected and processed. It emphasizes the importance of obtaining explicit consent from the data subject, particularly when dealing with sensitive and critical personal data. Additionally, it specifies that if a data controller has already complied with the necessary requirements during the first collection of personal data, they may not need to repeat those requirements for subsequent collections within a specified timeframe, provided certain conditions are met. The section also clarifies that personal data processed solely for personal, family, or household affairs is exempt from the provisions of the Act.
# ==================================================
# Question 3: ### Brief Description:
# Response 3: The document outlines various aspects of data protection and privacy laws, including definitions of key terms, the rights of data subjects, the responsibilities of data controllers and processors, and the establishment and functions of a regulatory commission. It covers topics such as consent for data processing, security requirements, data retention, and the rights to access, correction, and erasure of personal data. Additionally, it addresses the processing of sensitive data, cross-border data transfers, and the consequences of unlawful data processing.
# ==================================================
# Question 4: This section outlines the legal requirements for the lawful and fair collection, processing, and disclosure of personal data, emphasizing the need for specified purposes and registration obligations for data controllers and processors.
# Response 4: The section establishes that personal data must be collected and processed lawfully and fairly, with a clear emphasis on the necessity of obtaining consent from the data subject prior to processing. It mandates that the data controller must ensure that the data is only used for the specified purposes communicated to the data subject. Additionally, data controllers are required to maintain records of all applications, notices, and requests related to the personal data they process. Compliance with these obligations is crucial for protecting the rights of data subjects and ensuring transparency in data handling practices.
# ==================================================
# Question 5: ### Questions:
# Response 5: It seems that the query is incomplete or missing specific questions. Please provide the questions you would like answered, and I will be happy to assist you.
# ==================================================
# Question 6: 1. What are the specified, explicit, and legitimate purposes for which personal data is collected?
# Response 6: Personal data may be collected for several specified, explicit, and legitimate purposes, including:
#
# 1. The performance of a contract to which the data subject is a party.
# 2. Taking steps at the request of the data subject to enter into a contract.
# 3. Compliance with any legal obligation to which the data controller is subject, other than contractual obligations.
# 4. Treatment, public health, medical or research purposes, or responding to medical emergencies that threaten the life or health of the data subject or others.
# 5. Exercising or defending any rights or obligations conferred or imposed by law on the data controller in connection with employment.
# 6. Protecting the vital interests of the data subject or another person when consent cannot be given or reasonably obtained.
# 7. Legal proceedings, obtaining legal advice, establishing, exercising, or defending legal rights, and the administration of justice under court orders.
# 8. Functions conferred by or under any written law.
# 9. Processing for the prevention, detection, investigation, or prosecution of criminal offenses, apprehension or prosecution of offenders, enforcement of legal rights or claims, and tax assessment or collection.
# 10. Preparing statistics or conducting research, provided the data is not used for other purposes and does not identify the data subject.
# ==================================================
# Question 7: 2. How does the data controller ensure that the data collected is adequate, relevant, and limited to these purposes?
# Response 7: The data controller ensures that the data collected is adequate, relevant, and limited to the purposes for which it is processed by providing a written notice to the data subject. This notice includes the legal basis for processing the personal data, the duration for which the data is likely to be processed and retained, and information about the source of the personal data. Additionally, the data controller must inform the data subject about their rights, including the right to request access and correction of their personal data, which helps ensure that only necessary data is collected and processed.
# ==================================================
# Question 8: 3. What is the process for registering with the Commission, and what information is required?
# Response 8: The provided information does not specify the exact process for registering with the Commission or the specific information required for registration. It primarily discusses the handling of complaints, the powers of the Commission, and its reporting and auditing processes. For detailed registration procedures and required information, it would be necessary to refer to additional sections of the relevant legislation or guidelines issued by the Commission.
# ==================================================
# Question 9: 4. How is a "significant" data controller or processor defined, and what criteria are used to determine this status?
# Response 9: The provided information does not include a definition or criteria for a "significant" data controller or processor. Therefore, it is not possible to answer the query based on the available context.
# ==================================================
# Question 10: 5. What measures are in place to ensure compliance with the Act for data controllers or processors operating outside Pakistan?
# Response 10: Data controllers or processors operating outside Pakistan must comply with the Act if they process personal data concerning any commercial or non-commercial activity, including profiling data subjects within the territory of Pakistan. Additionally, if they do not have a physical presence in Pakistan, they are still subject to the Act when processing personal data in a territory where Pakistani law applies under public or private international law. This ensures that even foreign entities are held accountable for their data processing activities involving Pakistani data subjects.
# ==================================================
# Question 11: ---
# Response 11: I'm sorry, but it seems that the query is missing. Could you please provide the specific question you would like answered?
# ==================================================
# Question 12: ## Section Title: Consent for Disclosure
# Response 12: The section regarding the extent of disclosure outlines the circumstances under which a data controller may disclose personal data for purposes other than those originally stated at the time of collection. Disclosure is permissible if the data subject has given consent, if it is necessary for crime prevention or detection, if required by law or court order, if the data controller believes they have the right to disclose, if they believe they have the data subject's consent, or if justified in the public interest as determined by the Commission.
# ==================================================
# Question 13: ### Brief Description:
# Response 13: The document outlines various aspects of data protection and privacy laws, including definitions of key terms, the rights of data subjects, the responsibilities of data controllers and processors, and the establishment and functions of a regulatory commission. It covers topics such as consent for data processing, security requirements, data retention, rights to access, correction, erasure, and the conditions for cross-border data transfer. Additionally, it addresses the unlawful processing of personal data and the need for compliance with established regulations.
# ==================================================
# Question 14: This section details the requirements for obtaining consent from data subjects before disclosing their personal data, including conditions for disclosure and the rights of data subjects regarding their consent.
# Response 14: Consent must be obtained from data subjects before processing their personal data. This consent should be free, specific, informed, and unambiguous, indicating the data subject's agreement to the processing for the specified purpose. The burden of proof for establishing consent lies with the data controller. Data subjects have the right to withdraw their consent at any time, and the data controller must cease processing the personal data within a reasonable time after such withdrawal, unless the processing is authorized by law or can occur without consent. Disclosure of personal data may occur under certain circumstances, such as with the data subject's consent, for legal requirements, or in the public interest, among others.
# ==================================================
# Question 15: ### Questions:
# Response 15: It seems that the query is incomplete or missing specific questions. Please provide the questions you would like answered, and I will be happy to assist you.
# ==================================================
# Question 16: 1. How is consent defined in the context of personal data disclosure?
# Response 16: Consent in the context of personal data disclosure is defined as a free, specific, informed, and unambiguous indication of the data subject's intentions that signifies agreement to the processing of their data for the specified purpose communicated to them. The burden of proof to establish that consent has been given lies with the data controller, and the data subject has the right to withdraw their consent at any time, with the consequences of such withdrawal being borne by the data subject.
# ==================================================
# Question 17: 2. Under what circumstances can personal data be disclosed without the data subject's consent?
# Response 17: Personal data can be disclosed without the data subject's consent under several circumstances, including:
#
# 1. When necessary for the performance of a contract to which the data subject is a party or for taking steps at the request of the data subject to enter into a contract.
# 2. For compliance with any legal obligation to which the data controller is subject, other than a contractual obligation.
# 3. To protect the vital interests of the data subject or another person, particularly when consent cannot be given or reasonably obtained.
# 4. For medical purposes by a healthcare professional or someone owing a duty of confidentiality equivalent to that of a healthcare professional.
# 5. In connection with legal proceedings, obtaining legal advice, or establishing, exercising, or defending legal rights.
# 6. For the administration of justice under court orders or for the exercise of functions conferred by law.
# 7. When the information has been made public by the data subject themselves.
#
# Additionally, personal data processed for journalistic, literary, or artistic purposes may also be exempt from certain provisions if it serves the public interest in freedom of expression or national security, provided there is express authorization.
# ==================================================
# Question 18: 3. What process must a data subject follow to withdraw their consent, and how is this communicated to the data controller?
# Response 18: A data subject must provide a written notice to withdraw their consent to the processing of personal data. This notice should be communicated directly to the data controller, who is then required to cease the processing of the personal data upon receiving the notice.
# ==================================================
# Question 19: 4. What penalties are imposed for failing to cease processing upon withdrawal of consent?
# Response 19: The penalty for failing to cease processing personal data upon withdrawal of consent is a fine not exceeding 50,000 USD or an equivalent amount in Pakistani Rupees.
# ==================================================
# Question 20: ---
# Response 20: I'm sorry, but it seems that the query is missing. Could you please provide the specific question you would like answered?
# ==================================================
# Question 21: ## Section Title: Data Breach Notification
# Response 21: The provided information does not include a specific section titled "Data Breach Notification." However, it does define "personal data breach" as a breach of security that leads to the accidental or unlawful destruction, loss, alteration, unauthorized disclosure of, or access to personal data. If you need details on how to handle data breaches or related obligations, please specify, and I can assist further.
# ==================================================
# Question 22: ### Brief Description:
# Response 22: The document outlines various aspects of data protection and privacy laws, including definitions of key terms, the rights of data subjects, the responsibilities of data controllers and processors, and the establishment and functions of a regulatory commission. It covers topics such as consent for data processing, security requirements, data retention, rights to access, correction, erasure, and the conditions for cross-border data transfer. Additionally, it addresses the unlawful processing of personal data and the need for compliance with established regulations.
# ==================================================
# Question 23: This section outlines the obligations of data controllers in the event of a personal data breach, including notification timelines and the required content of breach notifications.
# Response 23: Data controllers are required to maintain a record of all personal data breaches, detailing the facts, effects, and remedial actions taken. Upon becoming aware of a breach, they must follow specific notification requirements. The data processor, while informing the data controller, is also obligated to comply with these requirements.
# ==================================================
# Question 24: ### Questions:
# Response 24: It seems that the query is incomplete or missing specific questions. Please provide the questions you would like answered, and I will be happy to assist you.
# ==================================================
# Question 25: 1. What is the timeline for notifying the Commission and data subjects in the event of a data breach?
# Response 25: The provided information does not specify a timeline for notifying the Commission and data subjects in the event of a data breach. It only mentions that the data controller must maintain a record of all personal data breaches and that the data processor should inform the data controller and the Commission after becoming aware of a breach. Further details on specific timelines for notifications are not included.
# ==================================================
# Question 26: 2. What information must be included in the notification of a personal data breach?
# Response 26: The notification of a personal data breach must include the following information:
#
# 1. The facts concerning the personal data breach.
# 2. The effects of the personal data breach.
# 3. The remedial action taken in response to the breach.
# ==================================================
# Question 27: 3. What are the conditions under which notification may not be required?
# Response 27: Notification may not be required under the following conditions:
#
# 1. When the processing is necessary for the performance of a contract to which the data subject is a party.
# 2. When taking steps at the request of the data subject to enter into a contract.
# 3. For compliance with any legal obligation to which the data controller is subject, other than an obligation imposed by a contract.
# 4. For treatment, public health, medical, or research purposes, or to respond to any medical emergency involving a threat to the life or health of the data subject or any other individual.
# 5. When the data subject has made the information public advertently.
# 6. When the processing is necessary for exercising or defending any right or obligation conferred or imposed by law on the data controller in connection with employment.
# 7. To protect the vital interests of the data subject or another person when consent cannot be given or reasonably expected.
# 8. For legal proceedings, obtaining legal advice, establishing, exercising, or defending legal rights, or for the administration of justice under court orders.
# 9. For the discharge of regulatory functions if the application of provisions would likely prejudice those functions.
# 10. For journalistic, literary, or artistic purposes, provided certain conditions regarding public interest and national security are met.
# ==================================================
# Question 28: 4. How does the data controller document and justify any delays in notification?
# Response 28: A data controller must document and justify any delays in notification by providing written notice to the requestor and the Commission before the expiration of the specified period. This notice should include the reasons for being unable to comply with the data correction request within the designated timeframe. Additionally, the data controller is required to maintain a record of all personal data breaches, which includes facts concerning the breaches, their effects, and the remedial actions taken.
# ==================================================
# Question 29: ---
# Response 29: I'm sorry, but it seems that the query is missing. Could you please provide the specific question you would like answered?
# ==================================================
# Question 30: ## Section Title: Security Requirements
# Response 30: The section on Security Requirements outlines the obligations of data controllers and processors to ensure the protection of personal data. It emphasizes the need for measures to safeguard personal data from loss, misuse, modification, unauthorized access, and other risks. Data controllers must implement practical security measures based on the nature of the data and potential harm from breaches. Additionally, data processors are required to comply with established security standards and are independently liable for ensuring these standards are met.
# ==================================================
# Question 31: ### Brief Description:
# Response 31: The document outlines various aspects of data protection and privacy laws, including definitions of key terms, the rights of data subjects, the responsibilities of data controllers and processors, and the establishment and functions of a regulatory commission. It covers topics such as consent for data processing, security requirements, data retention, rights to access, correction, and erasure of personal data, as well as provisions for cross-border data transfer and the handling of sensitive data. Additionally, it addresses the consequences of unlawful data processing and the need for compliance with established regulations.
# ==================================================
# Question 32: This section specifies the security measures that data controllers and processors must implement to protect personal data from various risks, as prescribed by the Commission.
# Response 32: Data controllers and processors are required to implement practical measures to safeguard personal data against risks such as loss, misuse, modification, unauthorized access, accidental disclosure, alteration, or destruction. These measures must consider the nature of the personal data and the potential harm that could arise from such incidents. Specific areas of focus include the storage location of the data, the security measures of the equipment used, the reliability and competence of personnel with access to the data, and the secure transfer of personal data. Additionally, data processors must comply with the prescribed technical and international security standards, and data controllers are responsible for ensuring this compliance.
# ==================================================
# Question 33: ### Questions:
# Response 33: It seems that the query is incomplete or missing specific questions. Please provide the questions you would like answered, and I will be happy to assist you.
# ==================================================
# Question 34: 1. What international security standards are recommended by the Commission for protecting personal data?
# Response 34: The Commission prescribes the best international standards to protect personal data from loss, misuse, modification, unauthorized or accidental access or disclosure, alteration, or destruction. Data controllers and processors are required to take practical measures to ensure the security of personal data, considering factors such as the storage location, security measures of the equipment, the reliability and competence of personnel with access, and secure transfer measures. Compliance with these technical and international standards is mandatory for data processors as well.
# ==================================================
# Question 35: 2. What specific security measures must data controllers and processors implement?
# Response 35: Data controllers and processors must implement practical measures to protect personal data, considering the nature of the data and potential harm from loss, misuse, modification, unauthorized access, or disclosure. Specific security measures include:
#
# 1. Ensuring the reliability, integrity, and competence of personnel with access to personal data.
# 2. Ensuring secure transfer of personal data.
# 3. Compliance with technical and international standards of organizational security as prescribed by the relevant authority.
# 4. Maintaining the security of the location where personal data is stored and any security measures incorporated into the equipment used for storage.
#
# Additionally, data controllers are responsible for ensuring that personal data is accurate, complete, and kept up to date.
# ==================================================
# Question 36: 3. How does the Commission ensure consistency and enforcement of these security measures across different levels of government?
# Response 36: The Commission ensures consistency and enforcement of security measures by advising the Federal Government and any other statutory authority on necessary actions to promote the protection of personal data. It monitors and enforces the application of the provisions of the Act, takes proactive steps to create public awareness, and engages with data controllers and processors to ensure compliance. Additionally, the Commission may suggest amendments to existing laws and regulations to align them with the provisions of the Act, thereby fostering a consistent approach across different levels of government.
# ==================================================
# Question 37: 4. What provisions exist for sharing sensitive personal data with the government?
# Response 37: The provided information does not specify provisions for sharing sensitive personal data with the government. It primarily discusses exemptions related to personal data processing for individual affairs, law enforcement, journalistic purposes, and the establishment of a Commission with various powers and functions. For detailed provisions regarding sharing sensitive personal data with the government, further context or specific sections addressing that topic would be needed.
# ==================================================
# Question 38: ---
# Response 38: I'm sorry, but it seems that the query is missing. Could you please provide the specific question you would like answered?
# ==================================================
# Question 39: ## Section Title: Record Keeping of Data Breaches
# Response 39: A data controller is required to maintain a record of all personal data breaches, which should include details about the breaches, their effects, and the remedial actions taken. Additionally, upon becoming aware of a personal data breach, a data processor must inform the data controller and the relevant commission, adhering to the notification requirements specified for personal data breaches.
# ==================================================
# Question 40: ### Brief Description:
# Response 40: The document outlines various aspects of data protection and privacy laws, including definitions of key terms, the rights of data subjects, the responsibilities of data controllers and processors, and the establishment and functions of a regulatory commission. It covers topics such as consent for data processing, security requirements, data retention, rights to access, correction, erasure, and the conditions for cross-border data transfers. Additionally, it addresses the unlawful processing of personal data and the need for compliance with established regulations.
# ==================================================
# Question 41: This section mandates the maintenance of records related to personal data breaches, detailing the information that must be documented and the notification process.
# Response 41: The section requires the data controller to maintain a record of all personal data breaches, which should include the facts surrounding the breaches, their effects, and the remedial actions taken. Additionally, upon becoming aware of a personal data breach, the data processor is obligated to inform the data controller and the commission, following the specified notification requirements.
# ==================================================
# Question 42: ### Questions:
# Response 42: It seems that the query is incomplete or missing specific questions. Please provide the questions you would like answered, and I will be happy to assist you.
# ==================================================
# Question 43: 1. What specific information must be included in the records of personal data breaches?
# Response 43: The records of personal data breaches must include the facts concerning the breaches, their effects, and the remedial action taken.
# ==================================================
# Question 44: 2. How does the data controller ensure timely notification of breaches to the Commission and affected data subjects?
# Response 44: The data controller is required to maintain a record of all personal data breaches, which includes details about the breach, its effects, and the remedial actions taken. Upon becoming aware of a personal data breach, the data processor must notify the data controller, who then has the responsibility to inform the Commission and the affected data subjects as per the established requirements for breach notification. This process ensures that timely notifications are made regarding any breaches.
# ==================================================
# Question 45: 3. What are the requirements for documenting the reasons for any delays in breach notifications?
# Response 45: The provided information does not specify the requirements for documenting the reasons for any delays in breach notifications. It primarily discusses the obligations of data controllers and processors regarding personal data breaches, including maintaining records of personal data breaches and the actions taken in response. For specific requirements related to documenting delays in breach notifications, further details would be needed.
# ==================================================
# Question 46: 4. How does the data controller address the potential consequences of a data breach in their records?
# Response 46: The data controller is required to maintain a record of all personal data breaches, which includes documenting the facts surrounding the breaches, their effects, and the remedial actions taken. This record-keeping helps ensure accountability and provides a basis for addressing any potential consequences arising from the breach.
# ==================================================
# Question 47: ---
# Response 47: I'm sorry, but it seems that the query is missing. Could you please provide the specific question you would like answered?
# ==================================================
# Question 48: ## Section Title: Language Accessibility
# Response 48: The provided context does not contain any information regarding "Language Accessibility." Therefore, I cannot provide an answer related to that section title.
# ==================================================
# Question 49: ### Brief Description:
# Response 49: The document outlines various aspects of data protection and privacy laws, including definitions of key terms, the rights of data subjects, the responsibilities of data controllers and processors, and the establishment and functions of a regulatory commission. It covers topics such as consent for data processing, security requirements, data retention, rights to access, correction, and erasure of personal data, as well as provisions for cross-border data transfer and the handling of sensitive data. The document also addresses the consequences of unlawful data processing and the need for compliance with established regulations.
# ==================================================
# Question 50: This section emphasizes the importance of providing notices in accessible languages to ensure that data subjects can understand the information regarding their personal data.
# Response 50: The section outlines the obligations of a data controller to inform data subjects about various aspects of their personal data, including its collection, processing, and their rights. While it does not explicitly mention the requirement for notices to be provided in accessible languages, the emphasis on clear communication implies that the information should be understandable to the data subjects. This ensures that individuals are fully aware of how their personal data is handled and their rights concerning it.
# ==================================================
# Question 51: ### Questions:
# Response 51: It seems that the query is incomplete or missing specific questions. Please provide the questions you would like answered, and I will be happy to assist you.
# ==================================================
# Question 52: 1. In which languages must notices be served according to the law?
# Response 52: The information provided does not specify the languages in which notices must be served according to the law.
# ==================================================
# Question 53: 2. What mechanisms are in place to allow individuals to choose their preferred language for communication?
# Response 53: The provided information does not specify any mechanisms for individuals to choose their preferred language for communication. It primarily discusses the processes related to the filing and handling of complaints by the Commission, including the acknowledgment of complaints, communication with data controllers or processors, and the use of electronic means for communication.
# ==================================================
# Question 54: 3. How does the data controller ensure that language accessibility is maintained in their privacy policies?
# Response 54: The provided information does not address how a data controller ensures language accessibility in their privacy policies. It primarily focuses on data processing, retention, integrity, and correction requirements. For specific measures regarding language accessibility, additional context would be needed.
# ==================================================
# Question 55: 4. Are there any specific compliance measures or penalties related to language accessibility that data controllers should be aware of?
# Response 55: The provided information does not mention any specific compliance measures or penalties related to language accessibility for data controllers. The focus is primarily on data security measures, data retention requirements, data integrity, and penalties for failing to adopt adequate security measures or comply with orders from the Commission.
# ==================================================
#
# Results have been saved to: data_protection_requirements.txt

# %%
# Step 1: Query the RAG System (using previously defined steps)
responses = []
for question in questions:
    response = query_engine.query(question)  # Query each question against RAG
    # Access the response content using the 'response' attribute instead of 'text'
    responses.append((question, response.response.strip()))  # Store question and response

# Step 2: Generate a Prompt for the LLM to Create a Checklist
llm_prompt = """
Using the following detailed responses, generate a checklist that outlines the compliance requirements an application's privacy policy must meet under the Pakistan Data Protection Law.

The checklist should:
- Be concise and clear.
- Use bullet points or numbered items.
- Group related requirements together under appropriate headings (e.g., "Lawful Processing", "Purpose Limitation").

Responses:
"""
for question, response in responses:
    llm_prompt += f"""
Question: {question.strip()}
Response: {response.strip()}
"""
llm_prompt += "\n"

llm_prompt += """
Ensure the checklist is practical and actionable, suitable for developers or legal teams to ensure compliance.
"""

# Step 3: Pass the Prompt to the LLM
checklist = query_engine.query(llm_prompt)  # Use the LLM to generate the checklist

# Step 4: Save the Checklist to a File
checklist_file_path = "privacy_policy_checklist.txt"

# %%
with open(checklist_file_path, "w") as file:
    # Access the response content using the 'response' attribute
    file.write(checklist.response.strip())  # Adjust attribute if needed for your query_engine

print(f"Checklist has been saved to: {checklist_file_path}")

# Step 5: Print the Checklist
print("\nGenerated Checklist:")
# Access the response content using the 'response' attribute
print(checklist.response.strip())
# Out:
# Checklist has been saved to: privacy_policy_checklist.txt
#
# Generated Checklist:
# ### Compliance Checklist for Privacy Policy under Pakistan Data Protection Law
#
# #### 1. **Lawful Processing**
# - Obtain explicit consent from data subjects before collecting or processing personal data.
# - Ensure that personal data is collected for specified, explicit, and legitimate purposes.
# - Maintain records of all applications, notices, and requests related to personal data processing.
#
# #### 2. **Purpose Limitation**
# - Clearly define and communicate the purposes for which personal data is collected.
# - Ensure that personal data is not processed in a manner incompatible with the stated purposes.
#
# #### 3. **Data Subject Rights**
# - Inform data subjects of their rights, including the right to access, correction, and erasure of their personal data.
# - Provide a mechanism for data subjects to request access to their personal data and receive a copy in an intelligible form.
#
# #### 4. **Data Security Measures**
# - Implement appropriate technical and organizational measures to protect personal data from loss, misuse, unauthorized access, and destruction.
# - Ensure compliance with international security standards as prescribed by the Commission.
#
# #### 5. **Data Breach Notification**
# - Maintain a record of all personal data breaches, including facts, effects, and remedial actions taken.
# - Notify the Commission and affected data subjects promptly upon becoming aware of a data breach.
#
# #### 6. **Data Retention and Deletion**
# - Establish and communicate a data retention policy that specifies how long personal data will be retained.
# - Ensure that personal data is deleted or anonymized when it is no longer necessary for the purposes for which it was collected.
#
# #### 7. **Cross-Border Data Transfers**
# - Assess and ensure compliance with regulations regarding the transfer of personal data outside Pakistan.
# - Obtain necessary consents or ensure that adequate safeguards are in place for cross-border data transfers.
#
# #### 8. **Complaint Handling**
# - Provide a clear process for data subjects to file complaints regarding data processing.
# - Acknowledge receipt of complaints within three working days and resolve them within thirty days.
#
# #### 9. **Language Accessibility**
# - Ensure that privacy notices and communications are provided in a language that is understandable to data subjects.
# - Consider providing notices in multiple languages if necessary to accommodate diverse populations.
#
# #### 10. **Documentation and Accountability**
# - Document all data processing activities, including the legal basis for processing and the categories of personal data involved.
# - Regularly review and update privacy policies and practices to ensure ongoing compliance with the law.
#
# This checklist serves as a practical guide for developers and legal teams to ensure that their applications' privacy policies align with the requirements of the Pakistan Data Protection Law.

# %%
# Step 1: Query the RAG System (using previously defined steps)
responses = []
for question in questions:
    response = query_engine.query(question)  # Query each question against RAG
    # Access the response content using the 'response' attribute instead of 'text'
    responses.append((question, response.response.strip()))  # Store question and response

# Step 2: Generate a Prompt for the LLM to Create a Checklist
llm_prompt = """
Using the following detailed responses, generate a checklist that outlines the compliance requirements an application's privacy policy must meet under the Pakistan Data Protection Law.

The checklist should:
- Be concise and clear.
- Use bullet points or numbered items.
- Group related requirements together under appropriate headings (e.g., "Lawful Processing", "Purpose Limitation").

Responses:
"""
for question, response in responses:
    llm_prompt += f"""
Question: {question.strip()}
Response: {response.strip()}
"""
llm_prompt += "\n"

llm_prompt += """
Ensure the checklist is practical and actionable, suitable for developers or legal teams to ensure compliance.
"""

# Step 3: Pass the Prompt to the LLM
checklist = query_engine.query(llm_prompt)  # Use the LLM to generate the checklist

# Step 4: Save the Checklist to a File
checklist_file_path = "privacy_policy_checklist.txt"

# Ensure the file is created and content is written before proceeding to the next step
with open(checklist_file_path, "w") as file:
    # Access the response content using the 'response' attribute
    file.write(checklist.response.strip())  # Adjust attribute if needed for your query_engine

print(f"Checklist has been saved to: {checklist_file_path}")

# Step 5: Print the Checklist
print("\nGenerated Checklist:")
# Access the response content using the 'response' attribute
print(checklist.response.strip())
# Out:
# Checklist has been saved to: privacy_policy_checklist.txt
#
# Generated Checklist:
# ### Compliance Checklist for Privacy Policy under Pakistan Data Protection Law
#
# #### 1. **Lawful Processing**
# - Obtain explicit consent from data subjects before collecting or processing personal data.
# - Ensure that personal data is collected for specified, explicit, and legitimate purposes.
# - Maintain records of all applications, notices, and requests related to personal data processing.
#
# #### 2. **Purpose Limitation**
# - Clearly define and communicate the purposes for which personal data is collected.
# - Limit data collection to what is adequate, relevant, and necessary for the stated purposes.
#
# #### 3. **Data Subject Rights**
# - Inform data subjects of their rights, including the right to access, correction, and erasure of their personal data.
# - Provide a mechanism for data subjects to request access to their personal data and to correct inaccuracies.
#
# #### 4. **Consent Management**
# - Implement processes for obtaining, managing, and withdrawing consent from data subjects.
# - Ensure that consent is free, specific, informed, and unambiguous.
#
# #### 5. **Complaint Handling**
# - Establish mechanisms for receiving and processing complaints related to data protection rights violations.
# - Acknowledge receipt of complaints within three working days and aim to resolve them within thirty days.
#
# #### 6. **Data Breach Notification**
# - Maintain a record of all personal data breaches, including facts, effects, and remedial actions taken.
# - Notify the Commission and affected data subjects promptly upon becoming aware of a data breach.
#
# #### 7. **Security Requirements**
# - Implement practical security measures to protect personal data from loss, misuse, unauthorized access, and destruction.
# - Comply with technical and international security standards as prescribed by the relevant authority.
#
# #### 8. **Record Keeping**
# - Document all personal data processing activities, including the purposes of processing and retention periods.
# - Maintain records of personal data breaches and the actions taken in response.
#
# #### 9. **Cross-Border Data Transfer**
# - Ensure compliance with regulations regarding the transfer of personal data outside Pakistan.
# - Verify that adequate protections are in place for data subjects when transferring data internationally.
#
# #### 10. **Language Accessibility**
# - Provide notices and communications in clear and accessible language to ensure understanding by data subjects.
# - Consider mechanisms for individuals to choose their preferred language for communication.
#
# #### 11. **Training and Awareness**
# - Conduct regular training for staff on data protection policies and compliance requirements.
# - Foster a culture of data protection awareness within the organization.
#
# This checklist serves as a practical guide for developers and legal teams to ensure compliance with the Pakistan Data Protection Law, facilitating the protection of personal data and the rights of data subjects.
