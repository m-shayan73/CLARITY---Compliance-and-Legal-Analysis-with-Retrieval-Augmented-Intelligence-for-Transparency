# %%
import pandas as pd
import os

# Create an empty DataFrame with the specified columns
opp_115 = pd.DataFrame(columns=['segment_id', 'policy_id', 'text', 'label'])

# Define the directory path
directory_path = '/Users/shayan/Desktop/LLM/OPP_115_Dataset'

# Iterate over all files in the directory
filenames = sorted(os.listdir(directory_path), key=lambda x: int(x.split('_')[0]))

for filename in filenames:
    if filename.endswith('.csv'):
        file_path = os.path.join(directory_path, filename)
        # Read the CSV file
        df = pd.read_csv(file_path)

        # Add the column names
        df.columns = ['segment_id', 'text', 'label']
        df['policy_id'] = filename.split('_')[0]

        # Merge labels for rows with the same id and policy_id
        df = df.groupby(['segment_id', 'policy_id'], as_index=False).agg({'text': 'first', 'label': lambda x: ', '.join(x)})
        
        # Concatenate the data to the main DataFrame
        opp_115 = pd.concat([opp_115, df], ignore_index=True)

# Now opp_115 contains all rows from the CSV files in the specified directory
opp_115
# Out:
#      segment_id policy_id                                               text  \
# 0             1        20  This privacy policy does not apply to Sites ma...
# 1             2        20  By visiting our Sites, you are accepting the p...
# 2             3        20   What Information Is Collected? We collect two...
# 3             4        20   Personally Identifiable Information As a gene...
# 4             5        20   Non-Personally Identifiable Information When ...
# ...         ...       ...                                                ...
# 3720         84      1713  Further, if you use any of the Communities fea...
# 3721         85      1713  b. Questions. If you have questions about this...
# 3722         86      1713  c. Sole Statement: This document is the sole s...
# 3723         87      1713  d. Other: Please review our Terms of Use Agree...
# 3724         88      1713  This Privacy Policy was last modified on the d...
#
#                                                   label
# 0            Introductory/Generic, Practice not covered
# 1                   Policy Change, Introductory/Generic
# 2                            First Party Collection/Use
# 3      Practice not covered, First Party Collection/Use
# 4                            First Party Collection/Use
# ...                                                 ...
# 3720  Introductory/Generic, Data Security, Third Par...
# 3721                        Privacy contact information
# 3722                               Introductory/Generic
# 3723                               Introductory/Generic
# 3724                               Introductory/Generic
#
# [3725 rows x 4 columns]

# %%
# Define the mapping dictionary
label_mapping = {
    'First Party Collection/Use': 1,
    'Third Party Sharing/Collection': 2,
    'User Choice/Control': 3,
    'User Access, Edit, & Deletion': 4,
    'User Access': 4,
    'Edit and Deletion': 4,
    'Data Retention': 5,
    'Data Security': 6,
    'Policy Change': 7,
    'Do Not Track': 8,
    'International and Specific Audiences': 9,
    'Privacy contact information': 10,
    'Practice not covered': 11,
    'Introductory/Generic': 12
}

only_others = 0
not_only_others = 0

# Replace the label text with corresponding numbers
for index, row in opp_115.iterrows():
    try:
        labels = row['label'].split(',')

        if labels[0].strip().isdigit():
            continue

        if len(labels) == 1 and labels[0] == 'Other':
            only_others += 1
            continue
        elif 'Other' in labels:
            not_only_others += 1
            continue

        mapped_labels = [str(label_mapping[label.strip()]) for label in labels]
        opp_115.at[index, 'label'] = ', '.join(mapped_labels)
    except Exception as e:
        print(e)
        print(row)

print("\n--------------------------------------------------------------------")
print('Number of rows with only "Other" label:', only_others)
print('Number of rows with "Other" label along with other labels:', not_only_others)
opp_115
# Out:
# 'Other'
# segment_id                                                    5
# policy_id                                                    21
# text           Information You Give Us : We receive and stor...
# label                         First Party Collection/Use, Other
# Name: 39, dtype: object
# 'Other'
# segment_id                                                    6
# policy_id                                                    21
# text           Automatic Information : We receive and store ...
# label                         First Party Collection/Use, Other
# Name: 40, dtype: object
# 'Other'
# segment_id                                                    8
# policy_id                                                    21
# text           Mobile : When you download or use apps create...
# label                         First Party Collection/Use, Other
# Name: 42, dtype: object
# 'Other'
# segment_id                                                    9
# policy_id                                                    21
# text           Information from Other Sources : We might rec...
# label                         First Party Collection/Use, Other
# Name: 43, dtype: object
# 'Other'
# segment_id                                                   21
# policy_id                                                    21
# text          IMDb also displays personalized third-party ad...
# label         Third Party Sharing/Collection, First Party Co...
# Name: 55, dtype: object
# 'Other'
# segment_id                                                   23
# policy_id                                                    21
# text          It is important for you to protect against una...
# label                Data Security, Introductory/Generic, Other
# Name: 57, dtype: object
# 'Other'
# segment_id                                                   30
# policy_id                                                    21
# text           Does IMDb.com Participate in the Safe Harbor ...
# label               International and Specific Audiences, Other
# Name: 64, dtype: object
# 'Other'
# segment_id                                                0
# policy_id                                                26
# text          Privacy Policy Last Updated on June 10, 2015
# label                           Introductory/Generic, Other
# Name: 70, dtype: object
# 'Other'
# segment_id                                                    2
# policy_id                                                    26
# text          The New York Times Replica Edition, maintained...
# label                               Other, Introductory/Generic
# Name: 72, dtype: object
# 'Other'
# segment_id                                                    3
# policy_id                                                    26
# text          The New York Times advertising portal, for adv...
# label                               Other, Introductory/Generic
# Name: 73, dtype: object
# 'Other'
# segment_id                                                    4
# policy_id                                                    26
# text          The NYT Services may contain links to other we...
# label                               Other, Introductory/Generic
# Name: 74, dtype: object
# 'Other'
# segment_id                                                    6
# policy_id                                                    26
# text          TRUSTe : The New York Times has received TRUST...
# label                                      Other, Data Security
# Name: 76, dtype: object
# 'Other'
# segment_id                                                    8
# policy_id                                                    26
# text          The TRUSTe program covers only information tha...
# label                               Other, Introductory/Generic
# Name: 78, dtype: object
# 'Other'
# segment_id                                                   13
# policy_id                                                    26
# text          Social media registration features may collect...
# label         First Party Collection/Use, Other, Third Party...
# Name: 83, dtype: object
# 'Other'
# segment_id                                                   16
# policy_id                                                    26
# text          User Generated Content and Public Activities (...
# label         Introductory/Generic, Third Party Sharing/Coll...
# Name: 86, dtype: object
# 'Other'
# segment_id                                                   17
# policy_id                                                    26
# text          Public activities may be included in our RSS f...
# label         Other, Third Party Sharing/Collection, Practic...
# Name: 87, dtype: object
# 'Other'
# segment_id                                                   21
# policy_id                                                    26
# text          Members of our Reader Panels agree to particip...
# label         First Party Collection/Use, Practice not cover...
# Name: 91, dtype: object
# 'Other'
# segment_id                                                   25
# policy_id                                                    26
# text          Cookies, Beacons, Local Storage and Other Simi...
# label         First Party Collection/Use, User Choice/Contro...
# Name: 95, dtype: object
# 'Other'
# segment_id                                                   26
# policy_id                                                    26
# text          We may transmit non-personally identifiable we...
# label                     Third Party Sharing/Collection, Other
# Name: 96, dtype: object
# 'Other'
# segment_id                                                   28
# policy_id                                                    26
# text          We may combine this automatically collected lo...
# label         Practice not covered, First Party Collection/U...
# Name: 98, dtype: object
# 'Other'
# segment_id                                                   31
# policy_id                                                    26
# text          The ads in our apps are not targeted to you ba...
# label                               Other, Practice not covered
# Name: 101, dtype: object
# 'Other'
# segment_id                                                   33
# policy_id                                                    26
# text          These companies may place or recognize cookies...
# label                     Third Party Sharing/Collection, Other
# Name: 103, dtype: object
# 'Other'
# segment_id                                                   34
# policy_id                                                    26
# text          We do not have access to, nor control over, th...
# label                               Other, Introductory/Generic
# Name: 104, dtype: object
# 'Other'
# segment_id                                                   35
# policy_id                                                    26
# text          Please click here to see a list of third parti...
# label                     Other, Third Party Sharing/Collection
# Name: 105, dtype: object
# 'Other'
# segment_id                                                   37
# policy_id                                                    26
# text          Your access to our websites should not be affe...
# label                               Other, Practice not covered
# Name: 107, dtype: object
# 'Other'
# segment_id                                                   41
# policy_id                                                    26
# text          Relevant Advertising We may use demographic an...
# label         First Party Collection/Use, Third Party Sharin...
# Name: 111, dtype: object
# 'Other'
# segment_id                                                   42
# policy_id                                                    26
# text          Email Newsletters The New York Times will peri...
# label                         Other, First Party Collection/Use
# Name: 112, dtype: object
# 'Other'
# segment_id                                                   49
# policy_id                                                    26
# text          We reserve the right to disclose your opt-out ...
# label         Practice not covered, Third Party Sharing/Coll...
# Name: 119, dtype: object
# 'Other'
# segment_id                                                   51
# policy_id                                                    26
# text          Email Newsletters. The New York Times offers s...
# label                                User Choice/Control, Other
# Name: 121, dtype: object
# 'Other'
# segment_id                                                   53
# policy_id                                                    26
# text          Emails From You. If you send us an email, we w...
# label                         Other, First Party Collection/Use
# Name: 123, dtype: object
# 'Other'
# segment_id                                                   64
# policy_id                                                    26
# text          The Learning Network. The Learning Network is ...
# label         International and Specific Audiences, Other, F...
# Name: 134, dtype: object
# 'Other'
# segment_id                                                   66
# policy_id                                                    26
# text          Your California Privacy Rights Under the Calif...
# label         International and Specific Audiences, Other, U...
# Name: 136, dtype: object
# 'Other'
# segment_id                                                   24
# policy_id                                                    32
# text           Security. We have implemented reasonable meas...
# label                                      Data Security, Other
# Name: 161, dtype: object
# 'Other'
# segment_id                                                   25
# policy_id                                                    32
# text           Links. The Services may contain links to othe...
# label                     Other, Third Party Sharing/Collection
# Name: 162, dtype: object
# 'Other'
# segment_id                                                   10
# policy_id                                                    33
# text          Information that you provide on message boards...
# label                         First Party Collection/Use, Other
# Name: 175, dtype: object
# 'Other'
# segment_id                                                   32
# policy_id                                                    33
# text          5. HOW WE SHARE YOUR INFORMATION Information s...
# label         Third Party Sharing/Collection, First Party Co...
# Name: 197, dtype: object
# 'Other'
# segment_id                                                   35
# policy_id                                                    33
# text          Social Networks: You may interact with certain...
# label                     Third Party Sharing/Collection, Other
# Name: 200, dtype: object
# 'Other'
# segment_id                                                   38
# policy_id                                                    33
# text          We may work with advertisers and third-party a...
# label         Third Party Sharing/Collection, Other, User Ch...
# Name: 203, dtype: object
# 'Other'
# segment_id                                                   44
# policy_id                                                    33
# text          7. HOW WE PROTECT YOUR INFORMATION We maintain...
# label                                      Data Security, Other
# Name: 209, dtype: object
# 'Other'
# segment_id                                                   45
# policy_id                                                    33
# text          Usernames & Passwords It is important that you...
# label                Data Security, Introductory/Generic, Other
# Name: 210, dtype: object
# 'Other'
# segment_id                                                   60
# policy_id                                                    33
# text          You should always read the Privacy Policy of a...
# label                Data Security, Introductory/Generic, Other
# Name: 225, dtype: object
# 'Other'
# segment_id                                                   14
# policy_id                                                    58
# text          g. Tracking Requests. Hearst does not act on D...
# label                                       Do Not Track, Other
# Name: 244, dtype: object
# 'Other'
# segment_id                                                   18
# policy_id                                                    58
# text          c. When you provide us your email address(e.g....
# label         Other, User Access, Edit and Deletion, Data Re...
# Name: 248, dtype: object
# 'Other'
# segment_id                                                   19
# policy_id                                                    58
# text          d. In addition, we may use information you pro...
# label         First Party Collection/Use, Other, Practice no...
# Name: 249, dtype: object
# 'Other'
# segment_id                                                   36
# policy_id                                                    58
# text          5. Right to Opt-out a. California Canadian Use...
# label         International and Specific Audiences, Other, P...
# Name: 266, dtype: object
# 'Other'
# segment_id                                                   38
# policy_id                                                    58
# text          c. Marketing provided by Hearst. From time to ...
# label         User Choice/Control, Other, Privacy contact in...
# Name: 268, dtype: object
# 'Other'
# segment_id                                                   40
# policy_id                                                    58
# text          e. Exceptions. If you have opted-out as descri...
# label                               Other, Practice not covered
# Name: 270, dtype: object
# 'Other'
# segment_id                                                   42
# policy_id                                                    58
# text          6. Wireless Email Address, Short MessageServic...
# label         User Choice/Control, Third Party Sharing/Colle...
# Name: 272, dtype: object
# 'Other'
# segment_id                                                   10
# policy_id                                                    59
# text          LINKS TO OTHER SITES As part of the service, L...
# label         Practice not covered, Third Party Sharing/Coll...
# Name: 286, dtype: object
# 'Other'
# segment_id                                                    2
# policy_id                                                    70
# text          Please read this summary and our updated priva...
# label                               Other, Introductory/Generic
# Name: 290, dtype: object
# 'Other'
# segment_id                                                   18
# policy_id                                                    70
# text           Contests and Other Promotions. From time to t...
# label         First Party Collection/Use, Third Party Sharin...
# Name: 306, dtype: object
# 'Other'
# segment_id                                                   30
# policy_id                                                    70
# text           Personalization and Tracking Technologies. Li...
# label         First Party Collection/Use, Other, Third Party...
# Name: 318, dtype: object
# 'Other'
# segment_id                                                   33
# policy_id                                                    70
# text           Social Network Posting Tools and "Share" Feat...
# label         Third Party Sharing/Collection, Other, Practic...
# Name: 321, dtype: object
# 'Other'
# segment_id                                                   34
# policy_id                                                    70
# text           Nielsen Online Campaign Ratings Service. Some...
# label         Third Party Sharing/Collection, User Choice/Co...
# Name: 322, dtype: object
# 'Other'
# segment_id                                                   57
# policy_id                                                    70
# text           Information You Post to Blogs, Discussion For...
# label                     Third Party Sharing/Collection, Other
# Name: 345, dtype: object
# 'Other'
# segment_id                                                   61
# policy_id                                                    70
# text           Interest-Based Advertising. Meredith follows ...
# label          Practice not covered, User Choice/Control, Other
# Name: 349, dtype: object
# 'Other'
# segment_id                                                   62
# policy_id                                                    70
# text          Most of the third-party advertising and data c...
# label         User Choice/Control, Other, Practice not cover...
# Name: 350, dtype: object
# 'Other'
# segment_id                                                   63
# policy_id                                                    70
# text          Adobe and Krux are other third parties we enga...
# label                     Third Party Sharing/Collection, Other
# Name: 351, dtype: object
# 'Other'
# segment_id                                                   65
# policy_id                                                    70
# text           Sites to Which We Link: We also may provide l...
# label         Practice not covered, Introductory/Generic, Other
# Name: 353, dtype: object
# 'Other'
# segment_id                                                   67
# policy_id                                                    70
# text           Security, Retention and Storage of Informatio...
# label                                      Data Security, Other
# Name: 355, dtype: object
# 'Other'
# segment_id                                                    8
# policy_id                                                    82
# text          New Technology: As we adopt additional technol...
# label         Practice not covered, First Party Collection/U...
# Name: 366, dtype: object
# 'Other'
# segment_id                                                    2
# policy_id                                                    93
# text          I. WHICH SITES ARE COVERED BY THIS POLICY- Thi...
# label                               Other, Introductory/Generic
# Name: 405, dtype: object
# 'Other'
# segment_id                                                    9
# policy_id                                                    93
# text          Your submission of others' Personally Identifi...
# label         First Party Collection/Use, Practice not cover...
# Name: 412, dtype: object
# 'Other'
# segment_id                                                   15
# policy_id                                                    93
# text          You can generally prevent cookies from being u...
# label                                User Choice/Control, Other
# Name: 418, dtype: object
# 'Other'
# segment_id                                                   18
# policy_id                                                    93
# text          We will typically explain the extent of use at...
# label                                User Choice/Control, Other
# Name: 421, dtype: object
# 'Other'
# segment_id                                                   25
# policy_id                                                    93
# text          On certain pages, we offer visitors the opport...
# label         Practice not covered, Third Party Sharing/Coll...
# Name: 428, dtype: object
# 'Other'
# segment_id                                                   26
# policy_id                                                    93
# text          We reserve the right to send you e-mail relati...
# label         Practice not covered, Other, First Party Colle...
# Name: 429, dtype: object
# 'Other'
# segment_id                                                   30
# policy_id                                                    93
# text          PBS uses cookies at the following times: A coo...
# label                         First Party Collection/Use, Other
# Name: 433, dtype: object
# 'Other'
# segment_id                                                   38
# policy_id                                                    93
# text          VIII. TERMS OF USE Please also make sure to re...
# label                               Other, Introductory/Generic
# Name: 441, dtype: object
# 'Other'
# segment_id                                                   39
# policy_id                                                    93
# text          The Privacy Policy posted on this Site was upd...
# label                               Other, Introductory/Generic
# Name: 442, dtype: object
# 'Other'
# segment_id                                             1
# policy_id                                             98
# text                       Last Updated on May 22, 2015
# label         Introductory/Generic, Other, Policy Change
# Name: 443, dtype: object
# 'Other'
# segment_id                                                    5
# policy_id                                                    98
# text          You can jump to specific areas of our Privacy ...
# label         Introductory/Generic, Other, International and...
# Name: 447, dtype: object
# 'Other'
# segment_id                                                   29
# policy_id                                                    98
# text          Unfortunately, no system or online transmissio...
# label                                      Data Security, Other
# Name: 471, dtype: object
# 'Other'
# segment_id                                                   32
# policy_id                                                    98
# text           Your Options for Cookies Web browsers allow s...
# label                                User Choice/Control, Other
# Name: 474, dtype: object
# 'Other'
# segment_id                                                   35
# policy_id                                                    98
# text           Social Networking and Third Party Sites When ...
# label         Introductory/Generic, Third Party Sharing/Coll...
# Name: 477, dtype: object
# 'Other'
# segment_id                                                   39
# policy_id                                                    98
# text           International This English-language Privacy P...
# label               International and Specific Audiences, Other
# Name: 481, dtype: object
# 'Other'
# segment_id                                                   11
# policy_id                                                   105
# text           Affiliated Businesses We Do Not Control: We w...
# label                     Third Party Sharing/Collection, Other
# Name: 493, dtype: object
# 'Other'
# segment_id                                                   13
# policy_id                                                   105
# text           Promotional Offers: Sometimes we send offers ...
# label         Third Party Sharing/Collection, User Choice/Co...
# Name: 495, dtype: object
# 'Other'
# segment_id                                                   30
# policy_id                                                   105
# text           Related Practices and Information Conditions ...
# label                               Other, Introductory/Generic
# Name: 512, dtype: object
# 'Other'
# segment_id                                                   33
# policy_id                                                   105
# text           Mobile Most mobile devices provide users with...
# label         User Choice/Control, Other, First Party Collec...
# Name: 515, dtype: object
# 'Other'
# segment_id                                                   35
# policy_id                                                   105
# text           Co-branded and Joint Offerings Examples of bu...
# label                     Other, Third Party Sharing/Collection
# Name: 517, dtype: object
# 'Other'
# segment_id                                                   23
# policy_id                                                   133
# text           Collection of Information by Third-Party Site...
# label         Introductory/Generic, Data Security, Other, Us...
# Name: 541, dtype: object
# 'Other'
# segment_id                                                   24
# policy_id                                                   133
# text          Time Inc. sites sometimes may offer contests, ...
# label         First Party Collection/Use, Third Party Sharin...
# Name: 542, dtype: object
# 'Other'
# segment_id                                                   26
# policy_id                                                   133
# text          For more information on advertisements and you...
# label         Introductory/Generic, Practice not covered, Other
# Name: 544, dtype: object
# 'Other'
# segment_id                                                   29
# policy_id                                                   133
# text          Most browsers automatically accept cookies. Yo...
# label         User Choice/Control, First Party Collection/Us...
# Name: 547, dtype: object
# 'Other'
# segment_id                                                   30
# policy_id                                                   133
# text          Local Shared Objects: Local shared objects, su...
# label         User Choice/Control, First Party Collection/Us...
# Name: 548, dtype: object
# 'Other'
# segment_id                                                   37
# policy_id                                                   133
# text          We encourage you to review, update, and correc...
# label         User Access, Edit and Deletion, User Choice/Co...
# Name: 555, dtype: object
# 'Other'
# segment_id                                               42
# policy_id                                               133
# text          This Privacy Policy was revised Jan. 2, 2014.
# label            Introductory/Generic, Policy Change, Other
# Name: 560, dtype: object
# 'Other'
# segment_id                                                    1
# policy_id                                                   135
# text           Important Update In September 2012, we announ...
# label                Other, Policy Change, Introductory/Generic
# Name: 561, dtype: object
# 'Other'
# segment_id                                                    2
# policy_id                                                   135
# text          We're updating our Privacy Policy to highlight...
# label                 Other, Policy Change, User Choice/Control
# Name: 562, dtype: object
# 'Other'
# segment_id                                                    3
# policy_id                                                   135
# text          Our new Privacy Policy is effective on January...
# label         Practice not covered, Policy Change, Introduct...
# Name: 563, dtype: object
# 'Other'
# segment_id                                                    4
# policy_id                                                   135
# text           Privacy Policy Effective date: January 19, 2013
# label                Other, Policy Change, Introductory/Generic
# Name: 564, dtype: object
# 'Other'
# segment_id                                                    5
# policy_id                                                   135
# text          Welcome to Instagram ("Instagram," "we," "us" ...
# label         Introductory/Generic, Other, User Choice/Contr...
# Name: 565, dtype: object
# 'Other'
# segment_id                                                    6
# policy_id                                                   135
# text          Click on the links below to jump to each secti...
# label                               Introductory/Generic, Other
# Name: 566, dtype: object
# 'Other'
# segment_id                                                    9
# policy_id                                                   135
# text          Finding your friends on Instagram: If you choo...
# label         Practice not covered, Other, First Party Colle...
# Name: 569, dtype: object
# 'Other'
# segment_id                                                   10
# policy_id                                                   135
# text           Note about "Invite Friends" feature: If you c...
# label          Practice not covered, Other, User Choice/Control
# Name: 570, dtype: object
# 'Other'
# segment_id                                                   12
# policy_id                                                   135
# text          Cookies and similar technologies: When you vis...
# label         First Party Collection/Use, Third Party Sharin...
# Name: 572, dtype: object
# 'Other'
# segment_id                                                   14
# policy_id                                                   135
# text          Device identifiers: When you use a mobile devi...
# label         First Party Collection/Use, Other, Third Party...
# Name: 574, dtype: object
# 'Other'
# segment_id                                                   23
# policy_id                                                   135
# text          Parties with whom you may choose to share your...
# label         Third Party Sharing/Collection, Practice not c...
# Name: 583, dtype: object
# 'Other'
# segment_id                                                   24
# policy_id                                                   135
# text          What happens in the event of a change of contr...
# label         Third Party Sharing/Collection, Other, Practic...
# Name: 584, dtype: object
# 'Other'
# segment_id                                                   26
# policy_id                                                   135
# text           4. HOW WE STORE YOUR INFORMATION Storage and ...
# label                               Introductory/Generic, Other
# Name: 586, dtype: object
# 'Other'
# segment_id                                                   30
# policy_id                                                   135
# text          We use commercially reasonable safeguards to h...
# label                                      Data Security, Other
# Name: 590, dtype: object
# 'Other'
# segment_id                                                   31
# policy_id                                                   135
# text          Please do your part to help us. You are respon...
# label                                                     Other
# Name: 591, dtype: object
# 'Other'
# segment_id                                                   32
# policy_id                                                   135
# text           5. YOUR CHOICES ABOUT YOUR INFORMATION Your a...
# label         User Access, Edit and Deletion, User Choice/Co...
# Name: 592, dtype: object
# 'Other'
# segment_id                                                   33
# policy_id                                                   135
# text          How long we keep your User Content: Following ...
# label                                     Data Retention, Other
# Name: 593, dtype: object
# 'Other'
# segment_id                                                   35
# policy_id                                                   135
# text           7. OTHER WEB SITES AND SERVICES We are not re...
# label                               Practice not covered, Other
# Name: 595, dtype: object
# 'Other'
# segment_id                                                   18
# policy_id                                                   144
# text           Transfer of Information: Your information may...
# label               Other, International and Specific Audiences
# Name: 616, dtype: object
# 'Other'
# segment_id                                                   26
# policy_id                                                   175
# text           Other Information No Spyware or Adware. We do...
# label                               Other, Practice not covered
# Name: 671, dtype: object
# 'Other'
# segment_id                                                   31
# policy_id                                                   186
# text           Definitions Aggregate Information. Aggregate ...
# label                               Introductory/Generic, Other
# Name: 709, dtype: object
# 'Other'
# segment_id                                                   32
# policy_id                                                   186
# text           Anonymous Information Anonymous information m...
# label                               Introductory/Generic, Other
# Name: 710, dtype: object
# 'Other'
# segment_id                                                   34
# policy_id                                                   186
# text           Children. Children means individuals who we h...
# label               International and Specific Audiences, Other
# Name: 712, dtype: object
# 'Other'
# segment_id                                                   36
# policy_id                                                   186
# text           Data Processor. A data processor is a person ...
# label                               Introductory/Generic, Other
# Name: 714, dtype: object
# 'Other'
# segment_id                                                   37
# policy_id                                                   186
# text           IP Address An IP address is associated with t...
# label         Introductory/Generic, Other, First Party Colle...
# Name: 715, dtype: object
# 'Other'
# segment_id                                                   38
# policy_id                                                   186
# text           Member Member means a subsidiary or affiliate...
# label                               Introductory/Generic, Other
# Name: 716, dtype: object
# 'Other'
# segment_id                                                   40
# policy_id                                                   186
# text           Parents Parents means a parent or legal guard...
# label               International and Specific Audiences, Other
# Name: 718, dtype: object
# 'Other'
# segment_id                                                   41
# policy_id                                                   186
# text           Personal information Personal information mea...
# label                               Introductory/Generic, Other
# Name: 719, dtype: object
# 'Other'
# segment_id                                                   43
# policy_id                                                   186
# text           The Walt Disney Family of Companies The Walt ...
# label                                                     Other
# Name: 721, dtype: object
# 'Other'
# segment_id                              0
# policy_id                             200
# text          Published: January 1, 2015
# label                               Other
# Name: 725, dtype: object
# 'Other'
# segment_id                                                   26
# policy_id                                                   200
# text           Links to Third-Party Sites Our Services may l...
# label         Introductory/Generic, Other, Practice not covered
# Name: 751, dtype: object
# 'Other'
# segment_id                                                   12
# policy_id                                                   202
# text          Cookies are used in the site in order to remem...
# label                         First Party Collection/Use, Other
# Name: 779, dtype: object
# 'Other'
# segment_id                                                   15
# policy_id                                                   202
# text           Public Forums Food Allergy Research & Educati...
# label         Other, Third Party Sharing/Collection, Data Se...
# Name: 782, dtype: object
# 'Other'
# segment_id                                                   28
# policy_id                                                   207
# text          When the user forgets the password associated ...
# label                Other, Data Security, Practice not covered
# Name: 821, dtype: object
# 'Other'
# segment_id                                                   40
# policy_id                                                   303
# text           involuntary pornography reddit is committed t...
# label         Other, Practice not covered, User Access, Edit...
# Name: 890, dtype: object
# 'Other'
# segment_id                                                   48
# policy_id                                                   303
# text           your app options notifications If you enable ...
# label                               Introductory/Generic, Other
# Name: 898, dtype: object
# 'Other'
# segment_id                                                    3
# policy_id                                                   331
# text           OUR COMMITMENTS TO YOUR FAMILY Like you, we h...
# label         International and Specific Audiences, Privacy ...
# Name: 968, dtype: object
# 'Other'
# segment_id                                                    6
# policy_id                                                   331
# text          Our ability to provide enhanced services may o...
# label                     Other, Third Party Sharing/Collection
# Name: 971, dtype: object
# 'Other'
# segment_id                                                   12
# policy_id                                                   331
# text          It is not our usual policy, but from time to t...
# label                     Third Party Sharing/Collection, Other
# Name: 977, dtype: object
# 'Other'
# segment_id                                                   13
# policy_id                                                   331
# text          There may be links that will let you leave our...
# label         Introductory/Generic, Practice not covered, Other
# Name: 978, dtype: object
# 'Other'
# segment_id                                                   0
# policy_id                                                  348
# text          Walmart Privacy Policy Last Updated: March 2015
# label                              Practice not covered, Other
# Name: 982, dtype: object
# 'Other'
# segment_id                                                   18
# policy_id                                                   348
# text           Cameras: We operate cameras in store for secu...
# label                               Practice not covered, Other
# Name: 1000, dtype: object
# 'Other'
# segment_id                                                   34
# policy_id                                                   348
# text          If you contact us by email or mail, please be ...
# label                                User Choice/Control, Other
# Name: 1016, dtype: object
# 'Other'
# segment_id                                                   35
# policy_id                                                   348
# text          Since we do not accept opt-out requests from t...
# label                                User Choice/Control, Other
# Name: 1017, dtype: object
# 'Other'
# segment_id                                                   36
# policy_id                                                   348
# text          Please know that, even if you opted out of rec...
# label         First Party Collection/Use, User Choice/Contro...
# Name: 1018, dtype: object
# 'Other'
# segment_id                                                   52
# policy_id                                                   348
# text           What Are Your Privacy Protections for Specifi...
# label                               Practice not covered, Other
# Name: 1034, dtype: object
# 'Other'
# segment_id                                                   53
# policy_id                                                   348
# text          We have additional specific notices for our pe...
# label         Practice not covered, International and Specif...
# Name: 1035, dtype: object
# 'Other'
# segment_id                                                   59
# policy_id                                                   348
# text          Please Contact Us with any questions, or to re...
# label                        Other, Privacy contact information
# Name: 1041, dtype: object
# 'Other'
# segment_id                              1
# policy_id                             359
# text            Posted: October 17, 2013
# label         Introductory/Generic, Other
# Name: 1044, dtype: object
# 'Other'
# segment_id                                                    9
# policy_id                                                   359
# text          Site Usage Information: We may receive and sto...
# label                         First Party Collection/Use, Other
# Name: 1052, dtype: object
# 'Other'
# segment_id                                                   16
# policy_id                                                   359
# text          Contests or Sweepstakes: We periodically opera...
# label         User Choice/Control, Third Party Sharing/Colle...
# Name: 1059, dtype: object
# 'Other'
# segment_id                                                   26
# policy_id                                                   359
# text          Here are three urls of third parties that disp...
# label         Data Security, Introductory/Generic, Practice ...
# Name: 1069, dtype: object
# 'Other'
# segment_id                                                   31
# policy_id                                                   359
# text          Links to other websites You should be aware th...
# label         Practice not covered, Introductory/Generic, Ot...
# Name: 1074, dtype: object
# 'Other'
# segment_id                                                   33
# policy_id                                                   359
# text          A special note for parents concerning privacy ...
# label               International and Specific Audiences, Other
# Name: 1076, dtype: object
# 'Other'
# segment_id                                                   34
# policy_id                                                   359
# text          The Internet offers children wonderful educati...
# label               International and Specific Audiences, Other
# Name: 1077, dtype: object
# 'Other'
# segment_id                                                   35
# policy_id                                                   359
# text          Your acceptance of the privacy policy and noti...
# label                                      Policy Change, Other
# Name: 1078, dtype: object
# 'Other'
# segment_id                                                   38
# policy_id                                                   359
# text          Your California privacy rights A California pr...
# label         International and Specific Audiences, User Cho...
# Name: 1081, dtype: object
# 'Other'
# segment_id                                                   39
# policy_id                                                   359
# text          Because this website has a comprehensive priva...
# label         International and Specific Audiences, Practice...
# Name: 1082, dtype: object
# 'Other'
# segment_id                                                   10
# policy_id                                                   414
# text           How You Can Control the Information We Collec...
# label                                User Choice/Control, Other
# Name: 1134, dtype: object
# 'Other'
# segment_id                                                   11
# policy_id                                                   414
# text          If you wish to make changes to any personal in...
# label         Privacy contact information, User Access, Edit...
# Name: 1135, dtype: object
# 'Other'
# segment_id                                                   14
# policy_id                                                   414
# text          Our Web advertising partners send us aggregate...
# label         Practice not covered, First Party Collection/U...
# Name: 1138, dtype: object
# 'Other'
# segment_id                                                   15
# policy_id                                                   414
# text          You also should be aware that our Web advertis...
# label         Third Party Sharing/Collection, User Choice/Co...
# Name: 1139, dtype: object
# 'Other'
# segment_id                                                   19
# policy_id                                                   414
# text           Governing Law This policy and the use of this...
# label         International and Specific Audiences, Practice...
# Name: 1143, dtype: object
# 'Other'
# segment_id                                                   22
# policy_id                                                   414
# text           Effective Date This Privacy Policy is effecti...
# label                Other, Policy Change, Introductory/Generic
# Name: 1146, dtype: object
# 'Other'
# segment_id                                                   21
# policy_id                                                   453
# text           Using specific features of Barnes & Noble Web...
# label                         First Party Collection/Use, Other
# Name: 1168, dtype: object
# 'Other'
# segment_id                                                   41
# policy_id                                                   453
# text          Please understand that Barnes & Noble does not...
# label         Introductory/Generic, Other, Practice not covered
# Name: 1188, dtype: object
# 'Other'
# segment_id                                                   44
# policy_id                                                   453
# text          To review Barnes & Noble's Mobile Privacy Supp...
# label                               Other, Introductory/Generic
# Name: 1191, dtype: object
# 'Other'
# segment_id                                                   79
# policy_id                                                   453
# text          Even if you opt-out of receiving promotional c...
# label                               Other, Introductory/Generic
# Name: 1226, dtype: object
# 'Other'
# segment_id                                                   81
# policy_id                                                   453
# text           Online Community Users Barnes & Noble provide...
# label         Data Retention, User Access, Edit and Deletion...
# Name: 1228, dtype: object
# 'Other'
# segment_id                                                   97
# policy_id                                                   453
# text          By doing business or interacting with Barnes &...
# label         Other, Practice not covered, International and...
# Name: 1244, dtype: object
# 'Other'
# segment_id                                                    4
# policy_id                                                   503
# text          If you wish, you can set your browser to refus...
# label         User Choice/Control, Privacy contact informati...
# Name: 1282, dtype: object
# 'Other'
# segment_id                                                   10
# policy_id                                                   503
# text           Links and Third-Party Content Our Sites may c...
# label         Third Party Sharing/Collection, Data Security,...
# Name: 1288, dtype: object
# 'Other'
# segment_id                                                   18
# policy_id                                                   503
# text          Overview of Changes from Previous Policy: We a...
# label                                                     Other
# Name: 1296, dtype: object
# 'Other'
# segment_id                                                    1
# policy_id                                                   517
# text          Kaleida Health is required by law to protect t...
# label         Other, Data Security, Introductory/Generic, Pr...
# Name: 1298, dtype: object
# 'Other'
# segment_id                                                   11
# policy_id                                                   517
# text          How Someone May Act On Your Behalf. You have t...
# label         International and Specific Audiences, Other, P...
# Name: 1308, dtype: object
# 'Other'
# segment_id                                                   12
# policy_id                                                   517
# text          Protections For HIV, Alcohol and Substance Abu...
# label                               Other, Practice not covered
# Name: 1309, dtype: object
# 'Other'
# segment_id                                                   13
# policy_id                                                   517
# text          How To Obtain A Copy Of This Notice. You have ...
# label         Other, Privacy contact information, Practice n...
# Name: 1310, dtype: object
# 'Other'
# segment_id                                                   15
# policy_id                                                   517
# text          How To File A Complaint. If you believe your p...
# label                        Other, Privacy contact information
# Name: 1312, dtype: object
# 'Other'
# segment_id                                                   49
# policy_id                                                   517
# text          Partially de-identified health information wil...
# ...
# 'Other'
# segment_id                             14
# policy_id                            1637
# text                         May 12, 2014
# label         Introductory/Generic, Other
# Name: 3431, dtype: object
# 'Other'
# segment_id                                                    1
# policy_id                                                  1666
# text          We provide a variety of online web services, m...
# label                Introductory/Generic, Other, Data Security
# Name: 3432, dtype: object
# 'Other'
# segment_id                                                    7
# policy_id                                                  1666
# text          For the same purposes, we use "cookies"---that...
# label         First Party Collection/Use, Practice not cover...
# Name: 3438, dtype: object
# 'Other'
# segment_id                                                    8
# policy_id                                                  1666
# text          Essentially, cookies are your identification c...
# label         Other, User Choice/Control, Introductory/Gener...
# Name: 3439, dtype: object
# 'Other'
# segment_id                                                   14
# policy_id                                                  1666
# text          We do not control the acts of users of the Ser...
# label         Other, Privacy contact information, Practice n...
# Name: 3445, dtype: object
# 'Other'
# segment_id                                                   17
# policy_id                                                  1666
# text          The Services may contain links to other Intern...
# label                               Practice not covered, Other
# Name: 3448, dtype: object
# 'Other'
# segment_id                                                   19
# policy_id                                                  1666
# text          We limit our own e-mail contact and solicitati...
# label                                User Choice/Control, Other
# Name: 3450, dtype: object
# 'Other'
# segment_id                                                   24
# policy_id                                                  1666
# text          We reserve the right to release any and all in...
# label                     Third Party Sharing/Collection, Other
# Name: 3455, dtype: object
# 'Other'
# segment_id                                                   30
# policy_id                                                  1666
# text          Effective date: July 1, 2004, Updated: Decembe...
# label                                      Other, Policy Change
# Name: 3461, dtype: object
# 'Other'
# segment_id                                                    1
# policy_id                                                  1673
# text          Welcome to Tulsaworld.com, home of the Tulsa W...
# label         Practice not covered, Introductory/Generic, Pr...
# Name: 3462, dtype: object
# 'Other'
# segment_id                                                    3
# policy_id                                                  1673
# text          PLEASE READ THIS PRIVACY POLICY CAREFULLY. BY ...
# label          User Choice/Control, Introductory/Generic, Other
# Name: 3464, dtype: object
# 'Other'
# segment_id                                                   18
# policy_id                                                  1673
# text          Some advertisers on Tulsaworld.com may use the...
# label         Third Party Sharing/Collection, Introductory/G...
# Name: 3479, dtype: object
# 'Other'
# segment_id                                                   26
# policy_id                                                  1673
# text          To use third party service providers. We provi...
# label         Third Party Sharing/Collection, First Party Co...
# Name: 3487, dtype: object
# 'Other'
# segment_id                                                   31
# policy_id                                                  1673
# text          Sale transaction information. From time to tim...
# label                     Third Party Sharing/Collection, Other
# Name: 3492, dtype: object
# 'Other'
# segment_id                                                   33
# policy_id                                                  1673
# text          What information is covered by this privacy po...
# label         First Party Collection/Use, Introductory/Gener...
# Name: 3494, dtype: object
# 'Other'
# segment_id                                                   34
# policy_id                                                  1673
# text          Information that you might post on a message b...
# label         Practice not covered, Introductory/Generic, Us...
# Name: 3495, dtype: object
# 'Other'
# segment_id                                                   35
# policy_id                                                  1673
# text          Please keep in mind that whenever you voluntar...
# label         Introductory/Generic, Third Party Sharing/Coll...
# Name: 3496, dtype: object
# 'Other'
# segment_id                                                   36
# policy_id                                                  1673
# text          Additionally, advertisers and vendors hosted o...
# label         Third Party Sharing/Collection, Introductory/G...
# Name: 3497, dtype: object
# 'Other'
# segment_id                                                   37
# policy_id                                                  1673
# text          Finally, you are solely responsible for mainta...
# label                Data Security, Introductory/Generic, Other
# Name: 3498, dtype: object
# 'Other'
# segment_id                                                   40
# policy_id                                                  1673
# text          You may accept certain kinds of contact and de...
# label                                User Choice/Control, Other
# Name: 3501, dtype: object
# 'Other'
# segment_id                                                   45
# policy_id                                                  1673
# text          Associated Press We participate in the News Re...
# label         Third Party Sharing/Collection, Introductory/G...
# Name: 3506, dtype: object
# 'Other'
# segment_id                                                   47
# policy_id                                                  1673
# text          Refunds Tulsa World will charge a $5 processin...
# label                               Practice not covered, Other
# Name: 3508, dtype: object
# 'Other'
# segment_id                                                   25
# policy_id                                                  1694
# text          What is "phishing"- "Phishing" is a scam where...
# label                Data Security, Other, Practice not covered
# Name: 3566, dtype: object
# 'Other'
# segment_id                                                   15
# policy_id                                                  1703
# text          While SRL will undertake efforts to see that a...
# label                Data Security, Introductory/Generic, Other
# Name: 3593, dtype: object
# 'Other'
# segment_id                                                   16
# policy_id                                                  1703
# text          This Site may contain links to other World Wid...
# label         Data Security, Introductory/Generic, Other, Th...
# Name: 3594, dtype: object
# 'Other'
# segment_id                                                   17
# policy_id                                                  1703
# text          6. Security Measures SRL has implemented numer...
# label         Data Security, Privacy contact information, Other
# Name: 3595, dtype: object
# 'Other'
# segment_id                                                   20
# policy_id                                                  1703
# text          9. Right to Change Privacy Statement SRL may c...
# label                                      Policy Change, Other
# Name: 3598, dtype: object
# 'Other'
# segment_id                                                    2
# policy_id                                                  1708
# text          By providing personal information to us and us...
# label         Practice not covered, Introductory/Generic, Other
# Name: 3600, dtype: object
# 'Other'
# segment_id                                                    9
# policy_id                                                  1708
# text          Cookies and other tracking technologies (such ...
# label         First Party Collection/Use, Third Party Sharin...
# Name: 3607, dtype: object
# 'Other'
# segment_id                                                   10
# policy_id                                                  1708
# text          Third parties that support the FSD Services by...
# label         Third Party Sharing/Collection, Other, User Ch...
# Name: 3608, dtype: object
# 'Other'
# segment_id                                                   11
# policy_id                                                  1708
# text          Most browsers are initially set to accept cook...
# label                 User Choice/Control, Data Security, Other
# Name: 3609, dtype: object
# 'Other'
# segment_id                                                   17
# policy_id                                                  1708
# text          Linked Services . The FSD Services may also be...
# label         User Choice/Control, Introductory/Generic, Pra...
# Name: 3615, dtype: object
# 'Other'
# segment_id                                                   19
# policy_id                                                  1708
# text          Collection of Personal Financial Information b...
# label         First Party Collection/Use, Third Party Sharin...
# Name: 3617, dtype: object
# 'Other'
# segment_id                                                   25
# policy_id                                                  1708
# text          To deliver relevant advertisements. FSD and ou...
# label         First Party Collection/Use, Third Party Sharin...
# Name: 3623, dtype: object
# 'Other'
# segment_id                                                   27
# policy_id                                                  1708
# text          To share with our Affiliates . FSD may share y...
# label                     Third Party Sharing/Collection, Other
# Name: 3625, dtype: object
# 'Other'
# segment_id                                                    9
# policy_id                                                  1713
# text           iii. In Connection with Promotions such as Co...
# label         First Party Collection/Use, User Choice/Contro...
# Name: 3645, dtype: object
# 'Other'
# segment_id                                                   31
# policy_id                                                  1713
# text          ii. In connection with Newsletters and other E...
# label          User Choice/Control, Practice not covered, Other
# Name: 3667, dtype: object
# 'Other'
# segment_id                                                   36
# policy_id                                                  1713
# text           You can opt-out of the use of Other Informati...
# label                                User Choice/Control, Other
# Name: 3672, dtype: object
# 'Other'
# segment_id                                                   38
# policy_id                                                  1713
# text           Please note the following with respect to opt...
# label          User Choice/Control, Practice not covered, Other
# Name: 3674, dtype: object
# 'Other'
# segment_id                                                   41
# policy_id                                                  1713
# text           You can prevent the use of certain Tracking T...
# label                                User Choice/Control, Other
# Name: 3677, dtype: object
# 'Other'
# segment_id                                                   42
# policy_id                                                  1713
# text           You can choose to have the Device you use to ...
# label          User Choice/Control, Other, Practice not covered
# Name: 3678, dtype: object
# 'Other'
# segment_id                                                   45
# policy_id                                                  1713
# text          iii. Flash Cookies. Please note that deleting,...
# label          Introductory/Generic, User Choice/Control, Other
# Name: 3681, dtype: object
# 'Other'
# segment_id                                                   52
# policy_id                                                  1713
# text          iii. Double Opt-in (SMS/SMS) Method: In respon...
# label         Other, User Choice/Control, First Party Collec...
# Name: 3688, dtype: object
# 'Other'
# segment_id                                                   59
# policy_id                                                  1713
# text           ii. Disclosure of Certain Information in Post...
# label                     Other, Third Party Sharing/Collection
# Name: 3695, dtype: object
# 'Other'
# segment_id                                                   60
# policy_id                                                  1713
# text           iii. Disclosure In Connection with Co-Branded...
# label         Third Party Sharing/Collection, Practice not c...
# Name: 3696, dtype: object
# 'Other'
# segment_id                                                   75
# policy_id                                                  1713
# text          In addition, Parents of children or Ineligible...
# label         International and Specific Audiences, Privacy ...
# Name: 3711, dtype: object
# 'Other'
# segment_id                                                   80
# policy_id                                                  1713
# text          All requests must be labeled "Your California ...
# label               International and Specific Audiences, Other
# Name: 3716, dtype: object
# 'Other'
# segment_id                                                   82
# policy_id                                                  1713
# text           11. Miscellaneous. a. Accuracy and Confidenti...
# label                               Other, Practice not covered
# Name: 3718, dtype: object
# 'Other'
# segment_id                                                   84
# policy_id                                                  1713
# text          Further, if you use any of the Communities fea...
# label         Introductory/Generic, Data Security, Third Par...
# Name: 3720, dtype: object
#
# --------------------------------------------------------------------
# Number of rows with only "Other" label: 18
# Number of rows with "Other" label along with other labels: 163
#      segment_id policy_id                                               text  \
# 0             1        20  This privacy policy does not apply to Sites ma...
# 1             2        20  By visiting our Sites, you are accepting the p...
# 2             3        20   What Information Is Collected? We collect two...
# 3             4        20   Personally Identifiable Information As a gene...
# 4             5        20   Non-Personally Identifiable Information When ...
# ...         ...       ...                                                ...
# 3720         84      1713  Further, if you use any of the Communities fea...
# 3721         85      1713  b. Questions. If you have questions about this...
# 3722         86      1713  c. Sole Statement: This document is the sole s...
# 3723         87      1713  d. Other: Please review our Terms of Use Agree...
# 3724         88      1713  This Privacy Policy was last modified on the d...
#
#                                                   label
# 0                                                12, 11
# 1                                                 7, 12
# 2                                                     1
# 3                                                 11, 1
# 4                                                     1
# ...                                                 ...
# 3720  Introductory/Generic, Data Security, Third Par...
# 3721                                                 10
# 3722                                                 12
# 3723                                                 12
# 3724                                                 12
#
# [3725 rows x 4 columns]

# %%
# Filter out rows where the label contains "Other"
opp_115_filtered = opp_115[~opp_115['label'].str.contains('Other')]

# Reset the index of the DataFrame
opp_115_filtered.reset_index(drop=True, inplace=True)

opp_115_filtered
# Out:
#      segment_id policy_id                                               text  \
# 0             1        20  This privacy policy does not apply to Sites ma...
# 1             2        20  By visiting our Sites, you are accepting the p...
# 2             3        20   What Information Is Collected? We collect two...
# 3             4        20   Personally Identifiable Information As a gene...
# 4             5        20   Non-Personally Identifiable Information When ...
# ...         ...       ...                                                ...
# 3141         83      1713  You are solely responsible for maintaining the...
# 3142         85      1713  b. Questions. If you have questions about this...
# 3143         86      1713  c. Sole Statement: This document is the sole s...
# 3144         87      1713  d. Other: Please review our Terms of Use Agree...
# 3145         88      1713  This Privacy Policy was last modified on the d...
#
#           label
# 0        12, 11
# 1         7, 12
# 2             1
# 3         11, 1
# 4             1
# ...         ...
# 3141  12, 6, 11
# 3142         10
# 3143         12
# 3144         12
# 3145         12
#
# [3146 rows x 4 columns]

# %%
opp_115_filtered.to_csv('opp_115_dataset_2.csv', index=False)
