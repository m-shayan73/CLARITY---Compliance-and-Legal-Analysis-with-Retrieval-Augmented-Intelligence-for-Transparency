# %% [markdown]
# # ChatGPT

# %% [markdown]
# ### Import Libraries

# %%
from openai import OpenAI
from pydantic import BaseModel
from sklearn.metrics import (
    classification_report,
    multilabel_confusion_matrix,
)
from tqdm.notebook import tqdm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
import random
import enum
import dotenv
import csv
import os

# %%
# Path to save the inferences
csv_file_path = "prompt2_4o_inferences_test.csv"

# %% [markdown]
# ### Load and Preprocess Dataset

# %%
opp_115 = pd.read_csv('../../opp_115_test.csv')
opp_115.head()
# Out:
#    segment_id  policy_id                                               text  \
# 0           2       1636  Our Web Sites may contain links to other websi...
# 1           5       1361   Yahoo's participation in the Safe Harbor prog...
# 2           2        919  Note: A cookie file contains unique informatio...
# 3          23        303   analytics cookies We use a tool called Google...
# 4           7        144  We reserve the right to access, use, and share...
#
#   label
# 0    10
# 1  6, 9
# 2    10
# 3  2, 1
# 4  2, 1

# %%
# One-hot encoding of labels
classes = list(range(1, 11))


def to_binary_matrix(y, classes):
    return np.array(
        [[1 if cls in curr_labels else 0 for cls in classes] for curr_labels in y]
    )


y_true = (
    opp_115["label"]
    .apply(lambda x: [int(i) for i in x.split(",")] if isinstance(x, str) else [])
    .tolist()
)
y_true_binary = to_binary_matrix(y_true, classes)
y_true_binary = y_true_binary.astype(bool)

# %% [markdown]
# ### Load Model and Define Model Configuration

# %%
# Define output classes
class Classification(enum.Enum):
    YES = "yes"
    NO = "no"


class ClassificationWithDescription(BaseModel):
    presence: Classification
    description: str


class CategoryClassification(BaseModel):
    first_party_collection_use: Classification
    third_party_sharing_collection: Classification
    user_choice_control: Classification
    user_access_edit_deletion: Classification
    data_retention: Classification
    data_security: Classification
    policy_change: Classification
    do_not_track: Classification
    international_specific_audiences: Classification
    other: Classification


class CategoryClassificationWithDescription(BaseModel):
    first_party_collection_use: ClassificationWithDescription
    third_party_sharing_collection: ClassificationWithDescription
    user_choice_control: ClassificationWithDescription
    user_access_edit_deletion: ClassificationWithDescription
    data_retention: ClassificationWithDescription
    data_security: ClassificationWithDescription
    policy_change: ClassificationWithDescription
    do_not_track: ClassificationWithDescription
    international_specific_audiences: ClassificationWithDescription
    other: ClassificationWithDescription

# %%
dotenv.load_dotenv("../.env")
openai_api_key = dotenv.get_key("../.env", "OPENAI_API_KEY")

# %%
client = OpenAI()

# %% [markdown]
# ### Define Categories

# %%
category_names = [
    "First Party Collection/Use",
    "Third Party Sharing/Collection",
    "User Choice/Control",
    "User Access, Edit, & Deletion",
    "Data Retention",
    "Data Security",
    "Policy Change",
    "Do Not Track",
    "International & Specific Audiences",
    "Other",
]

category_descriptions = [
    "how and why a service provider collects user information.",
    "how user information may be shared with or collected by third parties.",
    "choices and control options available to users.",
    "if and how users may access, edit, or delete their information.",
    "how long user information is stored.",
    "how user information is protected.",
    "if and how users will be informed about changes to the privacy policy.",
    "if and how Do Not Track signals for online tracking and advertising are honored.",
    "practices that pertain only to a specific group of users (e.g., children, Europeans, or California residents).",
    "includes privacy contact information, introductory or generic text, or data practices not covered in the above categories.",
]

categories_names_str = "\n".join(
    [f"{i+1}. {name}" for i, name in enumerate(category_names)]
)

category_names_with_description_str = "\n".join(
    [
        f"{i+1}. {name}: {description}"
        for i, (name, description) in enumerate(
            zip(category_names, category_descriptions)
        )
    ]
)

# %% [markdown]
# ### Run the Inferences using Prompt 1

# %%
inferences = {}
current_idx = 0
max_idx = len(opp_115)
num_rate_limit_retries = 0

# %%
# Check if the there are any exisitng inferences saved in a CSV file
csv_exist = False

if os.path.exists(csv_file_path):
    csv_exist = True

    # Load the CSV file and add the existing inferences to the inferences dictionary
    existing_inferences = pd.read_csv(csv_file_path)

    # Add the existing data to inferences
    for _, row in existing_inferences.iterrows():
        policy_id = row["policy_id"]
        segment_id = row["segment_id"]
        classification = CategoryClassification(
            first_party_collection_use=Classification(
                row["first_party_collection_use"]
            ),
            third_party_sharing_collection=Classification(
                row["third_party_sharing_collection"]
            ),
            user_choice_control=Classification(row["user_choice_control"]),
            user_access_edit_deletion=Classification(row["user_access_edit_deletion"]),
            data_retention=Classification(row["data_retention"]),
            data_security=Classification(row["data_security"]),
            policy_change=Classification(row["policy_change"]),
            do_not_track=Classification(row["do_not_track"]),
            international_specific_audiences=Classification(
                row["international_specific_audiences"]
            ),
            other=Classification(row["other"]),
        )
        inferences[(policy_id, segment_id)] = classification

while current_idx < max_idx:
    policy_id = opp_115.iloc[current_idx]["policy_id"]
    segment_id = opp_115.iloc[current_idx]["segment_id"]

    if (policy_id, segment_id) in inferences:
        current_idx += 1
        continue
    else:
        break

print(f"Starting from index {current_idx}")
# Out:
# Starting from index 2980

# %%
# Initialize tqdm progress bar
progress_bar = tqdm(total=max_idx, desc="Running Inferences")
progress_bar.update(current_idx)

# Loop through the records and run the inferences
while current_idx < max_idx:
    try:
        current_record = opp_115.iloc[current_idx]
        text = current_record["text"]
        policy_id = current_record["policy_id"]
        segment_id = current_record["segment_id"]

        if (policy_id, segment_id) in inferences:
            current_idx += 1
            progress_bar.update(1)
            continue

        # Run the inference
        system_prompt = "You are an expert legal language model specializing in privacy policy analysis. Your task is to evaluate a given text segment to determine its relevance to specific privacy policy categories. For each category, provide a structured JSON response indicating whether the text fits the category."
        user_prompt = f"""
Text Segment:
\" {text} \"

Category Names With Descriptions:
{category_names_with_description_str}
            """

        response = client.beta.chat.completions.parse(
            model="gpt-4o-mini",
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_prompt},
            ],
            temperature=0,
            response_format=CategoryClassification,
        )

        # Stores the json response in the inferences dictionary for later use
        inferences[(policy_id, segment_id)] = response.choices[0].message.parsed

        current_idx += 1
        progress_bar.update(1)

    # In case of hitting the rate limit
    except Exception as e:
        print(e)
        if num_rate_limit_retries >= 5:
            print(f"At record {current_idx}")
            break

        time.sleep(random.randint(5, 15))
        num_rate_limit_retries += 1

# Close the progress bar
progress_bar.close()
# Out:
# Running Inferences:   0%|          | 0/2980 [00:00<?, ?it/s]

# %% [markdown]
# ### Save the Inferences to a CSV

# %%
# Define the Columns in the CSV (Header)
header = [
    "policy_id",
    "segment_id",
    "first_party_collection_use",
    "third_party_sharing_collection",
    "user_choice_control",
    "user_access_edit_deletion",
    "data_retention",
    "data_security",
    "policy_change",
    "do_not_track",
    "international_specific_audiences",
    "other",
]

# Convert the inferences dict in a format suitable for csv format
csv_data = []
for (policy_id, segment_id), classification in inferences.items():
    row = [
        policy_id,
        segment_id,
        classification.first_party_collection_use.value,
        classification.third_party_sharing_collection.value,
        classification.user_choice_control.value,
        classification.user_access_edit_deletion.value,
        classification.data_retention.value,
        classification.data_security.value,
        classification.policy_change.value,
        classification.do_not_track.value,
        classification.international_specific_audiences.value,
        classification.other.value,
    ]
    csv_data.append(row)

# Write/Append the data to CSV
with open("prompt2_4o_inferences_test.csv", mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(header)
    writer.writerows(csv_data)

print("CSV file created successfully.")
# Out:
# CSV file created successfully.

# %% [markdown]
# ### Evaluation

# %%
# Extract predicted labels from the inferences
y_pred_binary = np.array([
    [
        inferences[(row["policy_id"], row["segment_id"])].first_party_collection_use == Classification.YES,
        inferences[(row["policy_id"], row["segment_id"])].third_party_sharing_collection == Classification.YES,
        inferences[(row["policy_id"], row["segment_id"])].user_choice_control == Classification.YES,
        inferences[(row["policy_id"], row["segment_id"])].user_access_edit_deletion == Classification.YES,
        inferences[(row["policy_id"], row["segment_id"])].data_retention == Classification.YES,
        inferences[(row["policy_id"], row["segment_id"])].data_security == Classification.YES,
        inferences[(row["policy_id"], row["segment_id"])].policy_change == Classification.YES,
        inferences[(row["policy_id"], row["segment_id"])].do_not_track == Classification.YES,
        inferences[(row["policy_id"], row["segment_id"])].international_specific_audiences == Classification.YES,
        inferences[(row["policy_id"], row["segment_id"])].other == Classification.YES,
    ]
    for _, row in opp_115.iterrows()
])

# %%
# Generate the multilabel confusion matrix
confusion_matrices = multilabel_confusion_matrix(y_true_binary, y_pred_binary)

fig, axes = plt.subplots(2, 5, figsize=(16, 6))
axes = axes.flatten()

for i, ax in enumerate(axes):
    sns.heatmap(confusion_matrices[i], annot=True, fmt="d", cmap="Blues", ax=ax)
    ax.set_title(f"Class {classes[i]}")
    ax.set_xlabel("Predicted")
    ax.set_ylabel("True")
    ax.xaxis.set_tick_params(rotation=0)
    ax.yaxis.set_tick_params(rotation=0)


# Add a footer to represent what each class number is
footer_text = "; ".join([f"Class {i+1}: {category_name}" for i, category_name in enumerate(category_names[0:5])])
footer_text += "\n"
footer_text += "; ".join([f"Class {i+6}: {category_name}" for i, category_name in enumerate(category_names[5:10])])
plt.figtext(0.5, -0.05, footer_text, ha="center", fontsize=10)
plt.tight_layout(pad=2.0)
plt.show()

# %%
# Calculate accuracy for each class
accuracies = (y_true_binary == y_pred_binary).mean(axis=0)
accuracy_per_class = dict(zip(category_names, accuracies))

accuracy_report = "                                   accuracy\n\n"
for category, accuracy in accuracy_per_class.items():

    accuracy_report += f"{category.rjust(34)} {accuracy:8.2f}\n"

print(accuracy_report)
# Calculate the average accuracy across all classes
average_accuracy = accuracies.mean()
print(f"Average Accuracy: {average_accuracy:.2f}")
# Out:
#                                    accuracy
#
#         First Party Collection/Use     0.86
#     Third Party Sharing/Collection     0.84
#                User Choice/Control     0.85
#      User Access, Edit, & Deletion     0.97
#                     Data Retention     0.97
#                      Data Security     0.95
#                      Policy Change     0.97
#                       Do Not Track     0.99
# International & Specific Audiences     0.98
#                              Other     0.67
#
# Average Accuracy: 0.91

# %%
# Generate the classification report
metrics_report = classification_report(y_true_binary, y_pred_binary, target_names=category_names)
print(metrics_report)
# Out:
#                                     precision    recall  f1-score   support
#
#         First Party Collection/Use       0.83      0.83      0.83      1223
#     Third Party Sharing/Collection       0.71      0.85      0.77       952
#                User Choice/Control       0.53      0.85      0.66       495
#      User Access, Edit, & Deletion       0.68      0.87      0.76       182
#                     Data Retention       0.70      0.63      0.67       123
#                      Data Security       0.73      0.71      0.72       289
#                      Policy Change       0.68      0.84      0.75       159
#                       Do Not Track       0.49      1.00      0.66        23
# International & Specific Audiences       0.89      0.89      0.89       284
#                              Other       0.89      0.30      0.45      1319
#
#                          micro avg       0.74      0.69      0.71      5049
#                          macro avg       0.71      0.78      0.72      5049
#                       weighted avg       0.78      0.69      0.69      5049
#                        samples avg       0.80      0.74      0.74      5049

# %%
# Find mismatches in each category
mismatches = {}

for i, category in enumerate(category_names):
    mismatches[category] = []

    for idx, (true_val, pred_val) in enumerate(zip(y_true_binary[:, i], y_pred_binary[:, i])):
        if true_val != pred_val:
            mismatches[category].append((idx, true_val, pred_val))

# Print mismatches
for category, mismatch_list in mismatches.items():
    print(f"Category: {category}")
    for idx, true_val, pred_val in mismatch_list:
        print(f"Index: {idx}, Actual: {true_val}, Predicted: {pred_val}")
    print("\n")
# Out:
# Category: First Party Collection/Use
# Index: 2, Actual: False, Predicted: True
# Index: 5, Actual: True, Predicted: False
# Index: 20, Actual: True, Predicted: False
# Index: 39, Actual: False, Predicted: True
# Index: 40, Actual: False, Predicted: True
# Index: 44, Actual: True, Predicted: False
# Index: 53, Actual: False, Predicted: True
# Index: 68, Actual: False, Predicted: True
# Index: 72, Actual: False, Predicted: True
# Index: 74, Actual: False, Predicted: True
# Index: 76, Actual: True, Predicted: False
# Index: 80, Actual: False, Predicted: True
# Index: 89, Actual: False, Predicted: True
# Index: 95, Actual: False, Predicted: True
# Index: 110, Actual: False, Predicted: True
# Index: 118, Actual: False, Predicted: True
# Index: 125, Actual: True, Predicted: False
# Index: 130, Actual: True, Predicted: False
# Index: 132, Actual: False, Predicted: True
# Index: 139, Actual: True, Predicted: False
# Index: 147, Actual: False, Predicted: True
# Index: 148, Actual: False, Predicted: True
# Index: 156, Actual: False, Predicted: True
# Index: 162, Actual: False, Predicted: True
# Index: 163, Actual: True, Predicted: False
# Index: 169, Actual: True, Predicted: False
# Index: 187, Actual: True, Predicted: False
# Index: 189, Actual: True, Predicted: False
# Index: 224, Actual: False, Predicted: True
# Index: 234, Actual: True, Predicted: False
# Index: 248, Actual: True, Predicted: False
# Index: 251, Actual: False, Predicted: True
# Index: 254, Actual: False, Predicted: True
# Index: 266, Actual: True, Predicted: False
# Index: 277, Actual: True, Predicted: False
# Index: 321, Actual: False, Predicted: True
# Index: 330, Actual: False, Predicted: True
# Index: 343, Actual: True, Predicted: False
# Index: 354, Actual: True, Predicted: False
# Index: 357, Actual: True, Predicted: False
# Index: 362, Actual: True, Predicted: False
# Index: 364, Actual: False, Predicted: True
# Index: 372, Actual: True, Predicted: False
# Index: 376, Actual: True, Predicted: False
# Index: 377, Actual: False, Predicted: True
# Index: 387, Actual: False, Predicted: True
# Index: 403, Actual: False, Predicted: True
# Index: 414, Actual: False, Predicted: True
# Index: 420, Actual: True, Predicted: False
# Index: 427, Actual: True, Predicted: False
# Index: 443, Actual: True, Predicted: False
# Index: 444, Actual: True, Predicted: False
# Index: 449, Actual: False, Predicted: True
# Index: 453, Actual: False, Predicted: True
# Index: 456, Actual: True, Predicted: False
# Index: 461, Actual: False, Predicted: True
# Index: 462, Actual: True, Predicted: False
# Index: 464, Actual: True, Predicted: False
# Index: 465, Actual: True, Predicted: False
# Index: 467, Actual: False, Predicted: True
# Index: 472, Actual: True, Predicted: False
# Index: 477, Actual: True, Predicted: False
# Index: 479, Actual: True, Predicted: False
# Index: 493, Actual: False, Predicted: True
# Index: 515, Actual: False, Predicted: True
# Index: 521, Actual: False, Predicted: True
# Index: 530, Actual: True, Predicted: False
# Index: 560, Actual: False, Predicted: True
# Index: 563, Actual: True, Predicted: False
# Index: 565, Actual: True, Predicted: False
# Index: 595, Actual: True, Predicted: False
# Index: 602, Actual: True, Predicted: False
# Index: 618, Actual: True, Predicted: False
# Index: 627, Actual: True, Predicted: False
# Index: 638, Actual: True, Predicted: False
# Index: 640, Actual: True, Predicted: False
# Index: 646, Actual: False, Predicted: True
# Index: 649, Actual: False, Predicted: True
# Index: 654, Actual: True, Predicted: False
# Index: 662, Actual: True, Predicted: False
# Index: 663, Actual: True, Predicted: False
# Index: 665, Actual: False, Predicted: True
# Index: 677, Actual: False, Predicted: True
# Index: 679, Actual: False, Predicted: True
# Index: 681, Actual: False, Predicted: True
# Index: 703, Actual: True, Predicted: False
# Index: 706, Actual: True, Predicted: False
# Index: 714, Actual: False, Predicted: True
# Index: 718, Actual: True, Predicted: False
# Index: 732, Actual: True, Predicted: False
# Index: 750, Actual: True, Predicted: False
# Index: 766, Actual: False, Predicted: True
# Index: 773, Actual: False, Predicted: True
# Index: 813, Actual: False, Predicted: True
# Index: 821, Actual: True, Predicted: False
# Index: 826, Actual: True, Predicted: False
# Index: 827, Actual: True, Predicted: False
# Index: 832, Actual: True, Predicted: False
# Index: 835, Actual: True, Predicted: False
# Index: 845, Actual: True, Predicted: False
# Index: 852, Actual: False, Predicted: True
# Index: 855, Actual: True, Predicted: False
# Index: 860, Actual: False, Predicted: True
# Index: 884, Actual: False, Predicted: True
# Index: 887, Actual: True, Predicted: False
# Index: 893, Actual: True, Predicted: False
# Index: 898, Actual: False, Predicted: True
# Index: 902, Actual: True, Predicted: False
# Index: 904, Actual: False, Predicted: True
# Index: 912, Actual: True, Predicted: False
# Index: 913, Actual: False, Predicted: True
# Index: 921, Actual: True, Predicted: False
# Index: 922, Actual: False, Predicted: True
# Index: 923, Actual: False, Predicted: True
# Index: 926, Actual: False, Predicted: True
# Index: 928, Actual: False, Predicted: True
# Index: 946, Actual: True, Predicted: False
# Index: 951, Actual: True, Predicted: False
# Index: 955, Actual: False, Predicted: True
# Index: 969, Actual: True, Predicted: False
# Index: 979, Actual: True, Predicted: False
# Index: 980, Actual: False, Predicted: True
# Index: 983, Actual: False, Predicted: True
# Index: 989, Actual: True, Predicted: False
# Index: 1013, Actual: True, Predicted: False
# Index: 1014, Actual: False, Predicted: True
# Index: 1029, Actual: False, Predicted: True
# Index: 1033, Actual: False, Predicted: True
# Index: 1034, Actual: True, Predicted: False
# Index: 1040, Actual: False, Predicted: True
# Index: 1046, Actual: True, Predicted: False
# Index: 1047, Actual: False, Predicted: True
# Index: 1065, Actual: True, Predicted: False
# Index: 1080, Actual: True, Predicted: False
# Index: 1092, Actual: True, Predicted: False
# Index: 1093, Actual: True, Predicted: False
# Index: 1095, Actual: True, Predicted: False
# Index: 1101, Actual: False, Predicted: True
# Index: 1103, Actual: False, Predicted: True
# Index: 1110, Actual: False, Predicted: True
# Index: 1129, Actual: False, Predicted: True
# Index: 1138, Actual: False, Predicted: True
# Index: 1146, Actual: True, Predicted: False
# Index: 1161, Actual: True, Predicted: False
# Index: 1163, Actual: False, Predicted: True
# Index: 1168, Actual: True, Predicted: False
# Index: 1174, Actual: False, Predicted: True
# Index: 1175, Actual: True, Predicted: False
# Index: 1190, Actual: False, Predicted: True
# Index: 1192, Actual: True, Predicted: False
# Index: 1194, Actual: True, Predicted: False
# Index: 1205, Actual: False, Predicted: True
# Index: 1217, Actual: True, Predicted: False
# Index: 1223, Actual: False, Predicted: True
# Index: 1240, Actual: True, Predicted: False
# Index: 1247, Actual: True, Predicted: False
# Index: 1251, Actual: False, Predicted: True
# Index: 1252, Actual: False, Predicted: True
# Index: 1263, Actual: False, Predicted: True
# Index: 1290, Actual: False, Predicted: True
# Index: 1291, Actual: True, Predicted: False
# Index: 1303, Actual: False, Predicted: True
# Index: 1305, Actual: True, Predicted: False
# Index: 1316, Actual: True, Predicted: False
# Index: 1317, Actual: True, Predicted: False
# Index: 1323, Actual: True, Predicted: False
# Index: 1339, Actual: False, Predicted: True
# Index: 1342, Actual: True, Predicted: False
# Index: 1352, Actual: False, Predicted: True
# Index: 1354, Actual: False, Predicted: True
# Index: 1355, Actual: True, Predicted: False
# Index: 1360, Actual: True, Predicted: False
# Index: 1365, Actual: True, Predicted: False
# Index: 1375, Actual: False, Predicted: True
# Index: 1382, Actual: True, Predicted: False
# Index: 1389, Actual: False, Predicted: True
# Index: 1392, Actual: True, Predicted: False
# Index: 1395, Actual: True, Predicted: False
# Index: 1416, Actual: False, Predicted: True
# Index: 1424, Actual: True, Predicted: False
# Index: 1438, Actual: True, Predicted: False
# Index: 1459, Actual: False, Predicted: True
# Index: 1475, Actual: True, Predicted: False
# Index: 1477, Actual: True, Predicted: False
# Index: 1478, Actual: True, Predicted: False
# Index: 1483, Actual: False, Predicted: True
# Index: 1490, Actual: False, Predicted: True
# Index: 1491, Actual: False, Predicted: True
# Index: 1506, Actual: True, Predicted: False
# Index: 1518, Actual: False, Predicted: True
# Index: 1521, Actual: False, Predicted: True
# Index: 1525, Actual: False, Predicted: True
# Index: 1530, Actual: True, Predicted: False
# Index: 1533, Actual: True, Predicted: False
# Index: 1538, Actual: False, Predicted: True
# Index: 1541, Actual: False, Predicted: True
# Index: 1551, Actual: True, Predicted: False
# Index: 1557, Actual: False, Predicted: True
# Index: 1561, Actual: True, Predicted: False
# Index: 1564, Actual: True, Predicted: False
# Index: 1565, Actual: True, Predicted: False
# Index: 1568, Actual: False, Predicted: True
# Index: 1584, Actual: True, Predicted: False
# Index: 1587, Actual: True, Predicted: False
# Index: 1594, Actual: True, Predicted: False
# Index: 1602, Actual: False, Predicted: True
# Index: 1609, Actual: True, Predicted: False
# Index: 1619, Actual: True, Predicted: False
# Index: 1622, Actual: False, Predicted: True
# Index: 1625, Actual: False, Predicted: True
# Index: 1636, Actual: True, Predicted: False
# Index: 1637, Actual: True, Predicted: False
# Index: 1643, Actual: True, Predicted: False
# Index: 1644, Actual: False, Predicted: True
# Index: 1669, Actual: False, Predicted: True
# Index: 1679, Actual: False, Predicted: True
# Index: 1683, Actual: False, Predicted: True
# Index: 1685, Actual: False, Predicted: True
# Index: 1690, Actual: False, Predicted: True
# Index: 1694, Actual: True, Predicted: False
# Index: 1695, Actual: True, Predicted: False
# Index: 1699, Actual: False, Predicted: True
# Index: 1704, Actual: False, Predicted: True
# Index: 1705, Actual: False, Predicted: True
# Index: 1706, Actual: True, Predicted: False
# Index: 1713, Actual: True, Predicted: False
# Index: 1747, Actual: True, Predicted: False
# Index: 1753, Actual: True, Predicted: False
# Index: 1765, Actual: False, Predicted: True
# Index: 1766, Actual: False, Predicted: True
# Index: 1772, Actual: False, Predicted: True
# Index: 1786, Actual: True, Predicted: False
# Index: 1810, Actual: False, Predicted: True
# Index: 1812, Actual: False, Predicted: True
# Index: 1816, Actual: True, Predicted: False
# Index: 1836, Actual: True, Predicted: False
# Index: 1840, Actual: False, Predicted: True
# Index: 1852, Actual: False, Predicted: True
# Index: 1857, Actual: False, Predicted: True
# Index: 1869, Actual: True, Predicted: False
# Index: 1879, Actual: False, Predicted: True
# Index: 1896, Actual: True, Predicted: False
# Index: 1898, Actual: True, Predicted: False
# Index: 1905, Actual: True, Predicted: False
# Index: 1909, Actual: False, Predicted: True
# Index: 1911, Actual: True, Predicted: False
# Index: 1916, Actual: True, Predicted: False
# Index: 1919, Actual: False, Predicted: True
# Index: 1924, Actual: False, Predicted: True
# Index: 1928, Actual: True, Predicted: False
# Index: 1933, Actual: False, Predicted: True
# Index: 1937, Actual: True, Predicted: False
# Index: 1942, Actual: False, Predicted: True
# Index: 1945, Actual: True, Predicted: False
# Index: 1951, Actual: False, Predicted: True
# Index: 1952, Actual: False, Predicted: True
# Index: 1965, Actual: True, Predicted: False
# Index: 1966, Actual: True, Predicted: False
# Index: 1968, Actual: True, Predicted: False
# Index: 1979, Actual: True, Predicted: False
# Index: 1985, Actual: False, Predicted: True
# Index: 1986, Actual: True, Predicted: False
# Index: 1987, Actual: False, Predicted: True
# Index: 1989, Actual: False, Predicted: True
# Index: 1998, Actual: True, Predicted: False
# Index: 2006, Actual: False, Predicted: True
# Index: 2007, Actual: True, Predicted: False
# Index: 2009, Actual: True, Predicted: False
# Index: 2012, Actual: True, Predicted: False
# Index: 2031, Actual: True, Predicted: False
# Index: 2032, Actual: True, Predicted: False
# Index: 2042, Actual: True, Predicted: False
# Index: 2052, Actual: True, Predicted: False
# Index: 2057, Actual: True, Predicted: False
# Index: 2069, Actual: True, Predicted: False
# Index: 2074, Actual: True, Predicted: False
# Index: 2076, Actual: True, Predicted: False
# Index: 2077, Actual: True, Predicted: False
# Index: 2087, Actual: False, Predicted: True
# Index: 2090, Actual: False, Predicted: True
# Index: 2102, Actual: True, Predicted: False
# Index: 2110, Actual: False, Predicted: True
# Index: 2118, Actual: False, Predicted: True
# Index: 2129, Actual: False, Predicted: True
# Index: 2135, Actual: True, Predicted: False
# Index: 2138, Actual: True, Predicted: False
# Index: 2147, Actual: True, Predicted: False
# Index: 2151, Actual: True, Predicted: False
# Index: 2152, Actual: True, Predicted: False
# Index: 2153, Actual: True, Predicted: False
# Index: 2161, Actual: True, Predicted: False
# Index: 2163, Actual: False, Predicted: True
# Index: 2189, Actual: True, Predicted: False
# Index: 2194, Actual: False, Predicted: True
# Index: 2196, Actual: False, Predicted: True
# Index: 2200, Actual: True, Predicted: False
# Index: 2206, Actual: False, Predicted: True
# Index: 2215, Actual: True, Predicted: False
# Index: 2219, Actual: True, Predicted: False
# Index: 2221, Actual: False, Predicted: True
# Index: 2223, Actual: False, Predicted: True
# Index: 2225, Actual: False, Predicted: True
# Index: 2227, Actual: False, Predicted: True
# Index: 2233, Actual: False, Predicted: True
# Index: 2242, Actual: False, Predicted: True
# Index: 2243, Actual: True, Predicted: False
# Index: 2246, Actual: False, Predicted: True
# Index: 2252, Actual: False, Predicted: True
# Index: 2264, Actual: False, Predicted: True
# Index: 2275, Actual: False, Predicted: True
# Index: 2276, Actual: True, Predicted: False
# Index: 2277, Actual: False, Predicted: True
# Index: 2288, Actual: False, Predicted: True
# Index: 2289, Actual: False, Predicted: True
# Index: 2291, Actual: True, Predicted: False
# Index: 2292, Actual: True, Predicted: False
# Index: 2306, Actual: False, Predicted: True
# Index: 2310, Actual: True, Predicted: False
# Index: 2329, Actual: False, Predicted: True
# Index: 2333, Actual: True, Predicted: False
# Index: 2334, Actual: True, Predicted: False
# Index: 2344, Actual: True, Predicted: False
# Index: 2345, Actual: True, Predicted: False
# Index: 2347, Actual: False, Predicted: True
# Index: 2352, Actual: True, Predicted: False
# Index: 2368, Actual: False, Predicted: True
# Index: 2378, Actual: False, Predicted: True
# Index: 2380, Actual: True, Predicted: False
# Index: 2386, Actual: False, Predicted: True
# Index: 2391, Actual: True, Predicted: False
# Index: 2396, Actual: False, Predicted: True
# Index: 2400, Actual: False, Predicted: True
# Index: 2401, Actual: False, Predicted: True
# Index: 2416, Actual: True, Predicted: False
# Index: 2434, Actual: False, Predicted: True
# Index: 2441, Actual: False, Predicted: True
# Index: 2444, Actual: True, Predicted: False
# Index: 2447, Actual: True, Predicted: False
# Index: 2451, Actual: False, Predicted: True
# Index: 2458, Actual: True, Predicted: False
# Index: 2470, Actual: True, Predicted: False
# Index: 2472, Actual: True, Predicted: False
# Index: 2477, Actual: True, Predicted: False
# Index: 2480, Actual: True, Predicted: False
# Index: 2482, Actual: True, Predicted: False
# Index: 2488, Actual: True, Predicted: False
# Index: 2502, Actual: False, Predicted: True
# Index: 2507, Actual: False, Predicted: True
# Index: 2518, Actual: False, Predicted: True
# Index: 2521, Actual: False, Predicted: True
# Index: 2527, Actual: True, Predicted: False
# Index: 2528, Actual: False, Predicted: True
# Index: 2540, Actual: True, Predicted: False
# Index: 2553, Actual: False, Predicted: True
# Index: 2555, Actual: False, Predicted: True
# Index: 2564, Actual: False, Predicted: True
# Index: 2565, Actual: False, Predicted: True
# Index: 2567, Actual: False, Predicted: True
# Index: 2574, Actual: False, Predicted: True
# Index: 2580, Actual: False, Predicted: True
# Index: 2581, Actual: False, Predicted: True
# Index: 2585, Actual: False, Predicted: True
# Index: 2593, Actual: False, Predicted: True
# Index: 2597, Actual: False, Predicted: True
# Index: 2604, Actual: False, Predicted: True
# Index: 2605, Actual: False, Predicted: True
# Index: 2606, Actual: False, Predicted: True
# Index: 2615, Actual: False, Predicted: True
# Index: 2629, Actual: False, Predicted: True
# Index: 2636, Actual: True, Predicted: False
# Index: 2638, Actual: True, Predicted: False
# Index: 2646, Actual: False, Predicted: True
# Index: 2664, Actual: True, Predicted: False
# Index: 2674, Actual: True, Predicted: False
# Index: 2680, Actual: False, Predicted: True
# Index: 2682, Actual: True, Predicted: False
# Index: 2686, Actual: True, Predicted: False
# Index: 2693, Actual: False, Predicted: True
# Index: 2695, Actual: False, Predicted: True
# Index: 2701, Actual: False, Predicted: True
# Index: 2702, Actual: True, Predicted: False
# Index: 2718, Actual: True, Predicted: False
# Index: 2719, Actual: False, Predicted: True
# Index: 2720, Actual: False, Predicted: True
# Index: 2723, Actual: True, Predicted: False
# Index: 2728, Actual: False, Predicted: True
# Index: 2742, Actual: True, Predicted: False
# Index: 2748, Actual: False, Predicted: True
# Index: 2749, Actual: False, Predicted: True
# Index: 2769, Actual: False, Predicted: True
# Index: 2781, Actual: False, Predicted: True
# Index: 2784, Actual: False, Predicted: True
# Index: 2787, Actual: False, Predicted: True
# Index: 2805, Actual: False, Predicted: True
# Index: 2806, Actual: True, Predicted: False
# Index: 2810, Actual: True, Predicted: False
# Index: 2813, Actual: False, Predicted: True
# Index: 2822, Actual: True, Predicted: False
# Index: 2823, Actual: False, Predicted: True
# Index: 2824, Actual: True, Predicted: False
# Index: 2839, Actual: False, Predicted: True
# Index: 2840, Actual: False, Predicted: True
# Index: 2847, Actual: False, Predicted: True
# Index: 2856, Actual: True, Predicted: False
# Index: 2858, Actual: True, Predicted: False
# Index: 2867, Actual: True, Predicted: False
# Index: 2869, Actual: False, Predicted: True
# Index: 2870, Actual: False, Predicted: True
# Index: 2874, Actual: False, Predicted: True
# Index: 2902, Actual: False, Predicted: True
# Index: 2911, Actual: True, Predicted: False
# Index: 2929, Actual: False, Predicted: True
# Index: 2942, Actual: False, Predicted: True
# Index: 2944, Actual: True, Predicted: False
# Index: 2969, Actual: False, Predicted: True
# Index: 2971, Actual: True, Predicted: False
# Index: 2977, Actual: False, Predicted: True
#
#
# Category: Third Party Sharing/Collection
# Index: 0, Actual: False, Predicted: True
# Index: 5, Actual: False, Predicted: True
# Index: 9, Actual: False, Predicted: True
# Index: 12, Actual: False, Predicted: True
# Index: 13, Actual: True, Predicted: False
# Index: 23, Actual: False, Predicted: True
# Index: 37, Actual: True, Predicted: False
# Index: 38, Actual: True, Predicted: False
# Index: 41, Actual: False, Predicted: True
# Index: 45, Actual: True, Predicted: False
# Index: 56, Actual: True, Predicted: False
# Index: 60, Actual: False, Predicted: True
# Index: 83, Actual: False, Predicted: True
# Index: 90, Actual: True, Predicted: False
# Index: 98, Actual: False, Predicted: True
# Index: 110, Actual: False, Predicted: True
# Index: 127, Actual: False, Predicted: True
# Index: 133, Actual: True, Predicted: False
# Index: 138, Actual: False, Predicted: True
# Index: 139, Actual: False, Predicted: True
# Index: 146, Actual: True, Predicted: False
# Index: 147, Actual: False, Predicted: True
# Index: 162, Actual: False, Predicted: True
# Index: 163, Actual: True, Predicted: False
# Index: 188, Actual: False, Predicted: True
# Index: 189, Actual: False, Predicted: True
# Index: 195, Actual: False, Predicted: True
# Index: 200, Actual: False, Predicted: True
# Index: 206, Actual: True, Predicted: False
# Index: 208, Actual: False, Predicted: True
# Index: 215, Actual: False, Predicted: True
# Index: 219, Actual: False, Predicted: True
# Index: 221, Actual: True, Predicted: False
# Index: 223, Actual: False, Predicted: True
# Index: 231, Actual: False, Predicted: True
# Index: 243, Actual: False, Predicted: True
# Index: 248, Actual: False, Predicted: True
# Index: 249, Actual: True, Predicted: False
# Index: 255, Actual: True, Predicted: False
# Index: 259, Actual: False, Predicted: True
# Index: 264, Actual: False, Predicted: True
# Index: 266, Actual: True, Predicted: False
# Index: 270, Actual: True, Predicted: False
# Index: 291, Actual: False, Predicted: True
# Index: 292, Actual: False, Predicted: True
# Index: 295, Actual: False, Predicted: True
# Index: 300, Actual: False, Predicted: True
# Index: 305, Actual: False, Predicted: True
# Index: 306, Actual: True, Predicted: False
# Index: 317, Actual: False, Predicted: True
# Index: 319, Actual: False, Predicted: True
# Index: 326, Actual: True, Predicted: False
# Index: 337, Actual: False, Predicted: True
# Index: 345, Actual: False, Predicted: True
# Index: 350, Actual: False, Predicted: True
# Index: 362, Actual: False, Predicted: True
# Index: 372, Actual: True, Predicted: False
# Index: 378, Actual: False, Predicted: True
# Index: 382, Actual: False, Predicted: True
# Index: 384, Actual: False, Predicted: True
# Index: 386, Actual: True, Predicted: False
# Index: 387, Actual: True, Predicted: False
# Index: 398, Actual: True, Predicted: False
# Index: 405, Actual: True, Predicted: False
# Index: 407, Actual: False, Predicted: True
# Index: 412, Actual: False, Predicted: True
# Index: 437, Actual: True, Predicted: False
# Index: 449, Actual: True, Predicted: False
# Index: 450, Actual: False, Predicted: True
# Index: 452, Actual: False, Predicted: True
# Index: 458, Actual: False, Predicted: True
# Index: 459, Actual: False, Predicted: True
# Index: 471, Actual: False, Predicted: True
# Index: 474, Actual: False, Predicted: True
# Index: 475, Actual: True, Predicted: False
# Index: 480, Actual: True, Predicted: False
# Index: 481, Actual: False, Predicted: True
# Index: 487, Actual: False, Predicted: True
# Index: 488, Actual: True, Predicted: False
# Index: 493, Actual: False, Predicted: True
# Index: 497, Actual: True, Predicted: False
# Index: 500, Actual: False, Predicted: True
# Index: 524, Actual: False, Predicted: True
# Index: 532, Actual: False, Predicted: True
# Index: 536, Actual: False, Predicted: True
# Index: 540, Actual: False, Predicted: True
# Index: 550, Actual: False, Predicted: True
# Index: 558, Actual: True, Predicted: False
# Index: 568, Actual: False, Predicted: True
# Index: 572, Actual: False, Predicted: True
# Index: 587, Actual: False, Predicted: True
# Index: 589, Actual: False, Predicted: True
# Index: 600, Actual: True, Predicted: False
# Index: 602, Actual: True, Predicted: False
# Index: 615, Actual: False, Predicted: True
# Index: 618, Actual: True, Predicted: False
# Index: 629, Actual: False, Predicted: True
# Index: 638, Actual: False, Predicted: True
# Index: 643, Actual: False, Predicted: True
# Index: 646, Actual: False, Predicted: True
# Index: 648, Actual: True, Predicted: False
# Index: 651, Actual: True, Predicted: False
# Index: 665, Actual: False, Predicted: True
# Index: 674, Actual: False, Predicted: True
# Index: 688, Actual: False, Predicted: True
# Index: 704, Actual: False, Predicted: True
# Index: 707, Actual: False, Predicted: True
# Index: 709, Actual: True, Predicted: False
# Index: 710, Actual: False, Predicted: True
# Index: 712, Actual: False, Predicted: True
# Index: 718, Actual: True, Predicted: False
# Index: 719, Actual: False, Predicted: True
# Index: 725, Actual: False, Predicted: True
# Index: 730, Actual: False, Predicted: True
# Index: 733, Actual: True, Predicted: False
# Index: 740, Actual: False, Predicted: True
# Index: 743, Actual: False, Predicted: True
# Index: 749, Actual: False, Predicted: True
# Index: 758, Actual: False, Predicted: True
# Index: 763, Actual: True, Predicted: False
# Index: 764, Actual: False, Predicted: True
# Index: 766, Actual: False, Predicted: True
# Index: 768, Actual: False, Predicted: True
# Index: 772, Actual: False, Predicted: True
# Index: 773, Actual: False, Predicted: True
# Index: 779, Actual: False, Predicted: True
# Index: 786, Actual: False, Predicted: True
# Index: 813, Actual: True, Predicted: False
# Index: 817, Actual: False, Predicted: True
# Index: 820, Actual: False, Predicted: True
# Index: 822, Actual: False, Predicted: True
# Index: 826, Actual: False, Predicted: True
# Index: 840, Actual: False, Predicted: True
# Index: 847, Actual: True, Predicted: False
# Index: 852, Actual: False, Predicted: True
# Index: 856, Actual: False, Predicted: True
# Index: 860, Actual: True, Predicted: False
# Index: 864, Actual: True, Predicted: False
# Index: 866, Actual: True, Predicted: False
# Index: 884, Actual: True, Predicted: False
# Index: 891, Actual: False, Predicted: True
# Index: 893, Actual: True, Predicted: False
# Index: 896, Actual: False, Predicted: True
# Index: 912, Actual: False, Predicted: True
# Index: 916, Actual: False, Predicted: True
# Index: 917, Actual: False, Predicted: True
# Index: 919, Actual: False, Predicted: True
# Index: 922, Actual: True, Predicted: False
# Index: 931, Actual: False, Predicted: True
# Index: 939, Actual: False, Predicted: True
# Index: 942, Actual: False, Predicted: True
# Index: 959, Actual: False, Predicted: True
# Index: 964, Actual: False, Predicted: True
# Index: 969, Actual: True, Predicted: False
# Index: 970, Actual: False, Predicted: True
# Index: 988, Actual: False, Predicted: True
# Index: 990, Actual: False, Predicted: True
# Index: 995, Actual: False, Predicted: True
# Index: 1009, Actual: True, Predicted: False
# Index: 1016, Actual: False, Predicted: True
# Index: 1028, Actual: False, Predicted: True
# Index: 1035, Actual: False, Predicted: True
# Index: 1040, Actual: False, Predicted: True
# Index: 1041, Actual: False, Predicted: True
# Index: 1045, Actual: False, Predicted: True
# Index: 1048, Actual: False, Predicted: True
# Index: 1053, Actual: False, Predicted: True
# Index: 1060, Actual: True, Predicted: False
# Index: 1061, Actual: True, Predicted: False
# Index: 1063, Actual: True, Predicted: False
# Index: 1072, Actual: False, Predicted: True
# Index: 1080, Actual: False, Predicted: True
# Index: 1082, Actual: False, Predicted: True
# Index: 1084, Actual: True, Predicted: False
# Index: 1089, Actual: False, Predicted: True
# Index: 1092, Actual: False, Predicted: True
# Index: 1097, Actual: False, Predicted: True
# Index: 1103, Actual: False, Predicted: True
# Index: 1146, Actual: True, Predicted: False
# Index: 1148, Actual: False, Predicted: True
# Index: 1153, Actual: False, Predicted: True
# Index: 1154, Actual: False, Predicted: True
# Index: 1162, Actual: True, Predicted: False
# Index: 1163, Actual: False, Predicted: True
# Index: 1169, Actual: False, Predicted: True
# Index: 1170, Actual: False, Predicted: True
# Index: 1176, Actual: False, Predicted: True
# Index: 1181, Actual: False, Predicted: True
# Index: 1184, Actual: False, Predicted: True
# Index: 1186, Actual: False, Predicted: True
# Index: 1194, Actual: False, Predicted: True
# Index: 1196, Actual: False, Predicted: True
# Index: 1226, Actual: True, Predicted: False
# Index: 1233, Actual: False, Predicted: True
# Index: 1238, Actual: False, Predicted: True
# Index: 1239, Actual: False, Predicted: True
# Index: 1240, Actual: False, Predicted: True
# Index: 1260, Actual: True, Predicted: False
# Index: 1267, Actual: False, Predicted: True
# Index: 1273, Actual: False, Predicted: True
# Index: 1290, Actual: False, Predicted: True
# Index: 1295, Actual: True, Predicted: False
# Index: 1297, Actual: True, Predicted: False
# Index: 1300, Actual: False, Predicted: True
# Index: 1306, Actual: False, Predicted: True
# Index: 1307, Actual: True, Predicted: False
# Index: 1309, Actual: True, Predicted: False
# Index: 1323, Actual: False, Predicted: True
# Index: 1328, Actual: False, Predicted: True
# Index: 1329, Actual: True, Predicted: False
# Index: 1332, Actual: True, Predicted: False
# Index: 1333, Actual: False, Predicted: True
# Index: 1337, Actual: False, Predicted: True
# Index: 1349, Actual: True, Predicted: False
# Index: 1352, Actual: True, Predicted: False
# Index: 1355, Actual: True, Predicted: False
# Index: 1359, Actual: False, Predicted: True
# Index: 1368, Actual: False, Predicted: True
# Index: 1369, Actual: False, Predicted: True
# Index: 1370, Actual: False, Predicted: True
# Index: 1381, Actual: False, Predicted: True
# Index: 1382, Actual: True, Predicted: False
# Index: 1389, Actual: False, Predicted: True
# Index: 1394, Actual: False, Predicted: True
# Index: 1397, Actual: False, Predicted: True
# Index: 1398, Actual: True, Predicted: False
# Index: 1403, Actual: True, Predicted: False
# Index: 1409, Actual: False, Predicted: True
# Index: 1410, Actual: True, Predicted: False
# Index: 1419, Actual: True, Predicted: False
# Index: 1426, Actual: True, Predicted: False
# Index: 1427, Actual: False, Predicted: True
# Index: 1452, Actual: False, Predicted: True
# Index: 1459, Actual: False, Predicted: True
# Index: 1462, Actual: True, Predicted: False
# Index: 1463, Actual: True, Predicted: False
# Index: 1469, Actual: False, Predicted: True
# Index: 1478, Actual: True, Predicted: False
# Index: 1484, Actual: False, Predicted: True
# Index: 1486, Actual: True, Predicted: False
# Index: 1496, Actual: False, Predicted: True
# Index: 1506, Actual: False, Predicted: True
# Index: 1509, Actual: False, Predicted: True
# Index: 1511, Actual: False, Predicted: True
# Index: 1512, Actual: False, Predicted: True
# Index: 1521, Actual: True, Predicted: False
# Index: 1525, Actual: False, Predicted: True
# Index: 1559, Actual: False, Predicted: True
# Index: 1565, Actual: False, Predicted: True
# Index: 1568, Actual: False, Predicted: True
# Index: 1569, Actual: True, Predicted: False
# Index: 1579, Actual: True, Predicted: False
# Index: 1580, Actual: False, Predicted: True
# Index: 1581, Actual: True, Predicted: False
# Index: 1593, Actual: True, Predicted: False
# Index: 1595, Actual: True, Predicted: False
# Index: 1601, Actual: False, Predicted: True
# Index: 1606, Actual: True, Predicted: False
# Index: 1608, Actual: True, Predicted: False
# Index: 1610, Actual: False, Predicted: True
# Index: 1622, Actual: True, Predicted: False
# Index: 1625, Actual: False, Predicted: True
# Index: 1632, Actual: False, Predicted: True
# Index: 1640, Actual: False, Predicted: True
# Index: 1643, Actual: False, Predicted: True
# Index: 1656, Actual: True, Predicted: False
# Index: 1679, Actual: False, Predicted: True
# Index: 1682, Actual: True, Predicted: False
# Index: 1687, Actual: False, Predicted: True
# Index: 1700, Actual: False, Predicted: True
# Index: 1712, Actual: True, Predicted: False
# Index: 1713, Actual: True, Predicted: False
# Index: 1719, Actual: True, Predicted: False
# Index: 1732, Actual: False, Predicted: True
# Index: 1733, Actual: True, Predicted: False
# Index: 1737, Actual: False, Predicted: True
# Index: 1751, Actual: True, Predicted: False
# Index: 1752, Actual: False, Predicted: True
# Index: 1758, Actual: False, Predicted: True
# Index: 1761, Actual: True, Predicted: False
# Index: 1764, Actual: False, Predicted: True
# Index: 1773, Actual: False, Predicted: True
# Index: 1779, Actual: False, Predicted: True
# Index: 1787, Actual: False, Predicted: True
# Index: 1790, Actual: False, Predicted: True
# Index: 1796, Actual: False, Predicted: True
# Index: 1797, Actual: True, Predicted: False
# Index: 1802, Actual: False, Predicted: True
# Index: 1810, Actual: False, Predicted: True
# Index: 1821, Actual: False, Predicted: True
# Index: 1832, Actual: False, Predicted: True
# Index: 1833, Actual: True, Predicted: False
# Index: 1838, Actual: False, Predicted: True
# Index: 1867, Actual: False, Predicted: True
# Index: 1868, Actual: False, Predicted: True
# Index: 1870, Actual: True, Predicted: False
# Index: 1875, Actual: False, Predicted: True
# Index: 1878, Actual: False, Predicted: True
# Index: 1892, Actual: False, Predicted: True
# Index: 1894, Actual: True, Predicted: False
# Index: 1897, Actual: False, Predicted: True
# Index: 1898, Actual: False, Predicted: True
# Index: 1903, Actual: False, Predicted: True
# Index: 1905, Actual: True, Predicted: False
# Index: 1906, Actual: False, Predicted: True
# Index: 1908, Actual: False, Predicted: True
# Index: 1911, Actual: False, Predicted: True
# Index: 1919, Actual: False, Predicted: True
# Index: 1923, Actual: False, Predicted: True
# Index: 1925, Actual: False, Predicted: True
# Index: 1933, Actual: True, Predicted: False
# Index: 1950, Actual: True, Predicted: False
# Index: 1951, Actual: False, Predicted: True
# Index: 1956, Actual: False, Predicted: True
# Index: 1965, Actual: False, Predicted: True
# Index: 1971, Actual: False, Predicted: True
# Index: 1976, Actual: False, Predicted: True
# Index: 1982, Actual: True, Predicted: False
# Index: 1985, Actual: False, Predicted: True
# Index: 1990, Actual: False, Predicted: True
# Index: 2002, Actual: True, Predicted: False
# Index: 2003, Actual: False, Predicted: True
# Index: 2011, Actual: False, Predicted: True
# Index: 2012, Actual: True, Predicted: False
# Index: 2013, Actual: False, Predicted: True
# Index: 2015, Actual: False, Predicted: True
# Index: 2016, Actual: True, Predicted: False
# Index: 2022, Actual: False, Predicted: True
# Index: 2027, Actual: True, Predicted: False
# Index: 2029, Actual: False, Predicted: True
# Index: 2030, Actual: True, Predicted: False
# Index: 2037, Actual: False, Predicted: True
# Index: 2041, Actual: False, Predicted: True
# Index: 2048, Actual: False, Predicted: True
# Index: 2067, Actual: False, Predicted: True
# Index: 2068, Actual: True, Predicted: False
# Index: 2070, Actual: False, Predicted: True
# Index: 2074, Actual: False, Predicted: True
# Index: 2075, Actual: False, Predicted: True
# Index: 2077, Actual: False, Predicted: True
# Index: 2083, Actual: False, Predicted: True
# Index: 2105, Actual: True, Predicted: False
# Index: 2109, Actual: False, Predicted: True
# Index: 2110, Actual: False, Predicted: True
# Index: 2114, Actual: True, Predicted: False
# Index: 2120, Actual: True, Predicted: False
# Index: 2125, Actual: False, Predicted: True
# Index: 2127, Actual: False, Predicted: True
# Index: 2135, Actual: False, Predicted: True
# Index: 2139, Actual: False, Predicted: True
# Index: 2143, Actual: False, Predicted: True
# Index: 2144, Actual: True, Predicted: False
# Index: 2165, Actual: True, Predicted: False
# Index: 2173, Actual: False, Predicted: True
# Index: 2180, Actual: False, Predicted: True
# Index: 2185, Actual: True, Predicted: False
# Index: 2207, Actual: True, Predicted: False
# Index: 2209, Actual: False, Predicted: True
# Index: 2210, Actual: False, Predicted: True
# Index: 2214, Actual: False, Predicted: True
# Index: 2217, Actual: False, Predicted: True
# Index: 2227, Actual: False, Predicted: True
# Index: 2239, Actual: False, Predicted: True
# Index: 2241, Actual: True, Predicted: False
# Index: 2243, Actual: False, Predicted: True
# Index: 2245, Actual: False, Predicted: True
# Index: 2250, Actual: False, Predicted: True
# Index: 2257, Actual: False, Predicted: True
# Index: 2273, Actual: True, Predicted: False
# Index: 2281, Actual: False, Predicted: True
# Index: 2287, Actual: False, Predicted: True
# Index: 2294, Actual: False, Predicted: True
# Index: 2310, Actual: False, Predicted: True
# Index: 2319, Actual: False, Predicted: True
# Index: 2320, Actual: False, Predicted: True
# Index: 2330, Actual: False, Predicted: True
# Index: 2336, Actual: True, Predicted: False
# Index: 2344, Actual: False, Predicted: True
# Index: 2358, Actual: False, Predicted: True
# Index: 2367, Actual: False, Predicted: True
# Index: 2380, Actual: True, Predicted: False
# Index: 2382, Actual: False, Predicted: True
# Index: 2383, Actual: False, Predicted: True
# Index: 2385, Actual: False, Predicted: True
# Index: 2388, Actual: True, Predicted: False
# Index: 2406, Actual: True, Predicted: False
# Index: 2409, Actual: False, Predicted: True
# Index: 2413, Actual: False, Predicted: True
# Index: 2418, Actual: True, Predicted: False
# Index: 2421, Actual: True, Predicted: False
# Index: 2423, Actual: False, Predicted: True
# Index: 2424, Actual: False, Predicted: True
# Index: 2451, Actual: False, Predicted: True
# Index: 2453, Actual: False, Predicted: True
# Index: 2457, Actual: False, Predicted: True
# Index: 2461, Actual: False, Predicted: True
# Index: 2467, Actual: False, Predicted: True
# Index: 2470, Actual: True, Predicted: False
# Index: 2472, Actual: False, Predicted: True
# Index: 2475, Actual: True, Predicted: False
# Index: 2477, Actual: True, Predicted: False
# Index: 2478, Actual: False, Predicted: True
# Index: 2485, Actual: False, Predicted: True
# Index: 2495, Actual: False, Predicted: True
# Index: 2511, Actual: True, Predicted: False
# Index: 2513, Actual: False, Predicted: True
# Index: 2521, Actual: False, Predicted: True
# Index: 2524, Actual: True, Predicted: False
# Index: 2549, Actual: False, Predicted: True
# Index: 2550, Actual: False, Predicted: True
# Index: 2552, Actual: False, Predicted: True
# Index: 2553, Actual: False, Predicted: True
# Index: 2554, Actual: False, Predicted: True
# Index: 2558, Actual: False, Predicted: True
# Index: 2562, Actual: True, Predicted: False
# Index: 2565, Actual: True, Predicted: False
# Index: 2573, Actual: True, Predicted: False
# Index: 2605, Actual: False, Predicted: True
# Index: 2612, Actual: False, Predicted: True
# Index: 2620, Actual: False, Predicted: True
# Index: 2639, Actual: False, Predicted: True
# Index: 2641, Actual: False, Predicted: True
# Index: 2646, Actual: True, Predicted: False
# Index: 2656, Actual: False, Predicted: True
# Index: 2660, Actual: True, Predicted: False
# Index: 2661, Actual: False, Predicted: True
# Index: 2680, Actual: False, Predicted: True
# Index: 2682, Actual: True, Predicted: False
# Index: 2687, Actual: True, Predicted: False
# Index: 2695, Actual: True, Predicted: False
# Index: 2700, Actual: True, Predicted: False
# Index: 2703, Actual: False, Predicted: True
# Index: 2708, Actual: True, Predicted: False
# Index: 2727, Actual: False, Predicted: True
# Index: 2730, Actual: True, Predicted: False
# Index: 2735, Actual: False, Predicted: True
# Index: 2737, Actual: False, Predicted: True
# Index: 2740, Actual: False, Predicted: True
# Index: 2744, Actual: False, Predicted: True
# Index: 2745, Actual: False, Predicted: True
# Index: 2757, Actual: False, Predicted: True
# Index: 2758, Actual: True, Predicted: False
# Index: 2760, Actual: False, Predicted: True
# Index: 2779, Actual: False, Predicted: True
# Index: 2784, Actual: False, Predicted: True
# Index: 2787, Actual: False, Predicted: True
# Index: 2807, Actual: False, Predicted: True
# Index: 2815, Actual: True, Predicted: False
# Index: 2816, Actual: False, Predicted: True
# Index: 2818, Actual: True, Predicted: False
# Index: 2834, Actual: True, Predicted: False
# Index: 2837, Actual: False, Predicted: True
# Index: 2843, Actual: False, Predicted: True
# Index: 2861, Actual: False, Predicted: True
# Index: 2870, Actual: False, Predicted: True
# Index: 2889, Actual: False, Predicted: True
# Index: 2894, Actual: True, Predicted: False
# Index: 2897, Actual: True, Predicted: False
# Index: 2904, Actual: True, Predicted: False
# Index: 2911, Actual: False, Predicted: True
# Index: 2922, Actual: False, Predicted: True
# Index: 2924, Actual: False, Predicted: True
# Index: 2931, Actual: False, Predicted: True
# Index: 2943, Actual: True, Predicted: False
# Index: 2948, Actual: True, Predicted: False
# Index: 2954, Actual: False, Predicted: True
# Index: 2956, Actual: False, Predicted: True
# Index: 2963, Actual: False, Predicted: True
# Index: 2965, Actual: True, Predicted: False
# Index: 2971, Actual: False, Predicted: True
#
#
# Category: User Choice/Control
# Index: 5, Actual: False, Predicted: True
# Index: 9, Actual: False, Predicted: True
# Index: 13, Actual: False, Predicted: True
# Index: 17, Actual: False, Predicted: True
# Index: 20, Actual: False, Predicted: True
# Index: 21, Actual: False, Predicted: True
# Index: 24, Actual: False, Predicted: True
# Index: 26, Actual: False, Predicted: True
# Index: 31, Actual: False, Predicted: True
# Index: 36, Actual: False, Predicted: True
# Index: 55, Actual: False, Predicted: True
# Index: 57, Actual: False, Predicted: True
# Index: 62, Actual: False, Predicted: True
# Index: 64, Actual: False, Predicted: True
# Index: 66, Actual: False, Predicted: True
# Index: 74, Actual: True, Predicted: False
# Index: 76, Actual: False, Predicted: True
# Index: 90, Actual: False, Predicted: True
# Index: 103, Actual: False, Predicted: True
# Index: 110, Actual: False, Predicted: True
# Index: 146, Actual: False, Predicted: True
# Index: 147, Actual: False, Predicted: True
# Index: 155, Actual: False, Predicted: True
# Index: 161, Actual: False, Predicted: True
# Index: 162, Actual: False, Predicted: True
# Index: 176, Actual: False, Predicted: True
# Index: 196, Actual: False, Predicted: True
# Index: 200, Actual: False, Predicted: True
# Index: 215, Actual: False, Predicted: True
# Index: 221, Actual: False, Predicted: True
# Index: 224, Actual: True, Predicted: False
# Index: 226, Actual: False, Predicted: True
# Index: 238, Actual: False, Predicted: True
# Index: 241, Actual: False, Predicted: True
# Index: 242, Actual: False, Predicted: True
# Index: 251, Actual: True, Predicted: False
# Index: 254, Actual: False, Predicted: True
# Index: 256, Actual: True, Predicted: False
# Index: 266, Actual: False, Predicted: True
# Index: 270, Actual: False, Predicted: True
# Index: 271, Actual: False, Predicted: True
# Index: 287, Actual: False, Predicted: True
# Index: 298, Actual: False, Predicted: True
# Index: 309, Actual: False, Predicted: True
# Index: 310, Actual: False, Predicted: True
# Index: 314, Actual: False, Predicted: True
# Index: 319, Actual: False, Predicted: True
# Index: 320, Actual: False, Predicted: True
# Index: 326, Actual: False, Predicted: True
# Index: 333, Actual: True, Predicted: False
# Index: 341, Actual: False, Predicted: True
# Index: 347, Actual: False, Predicted: True
# Index: 352, Actual: True, Predicted: False
# Index: 366, Actual: True, Predicted: False
# Index: 373, Actual: False, Predicted: True
# Index: 382, Actual: False, Predicted: True
# Index: 389, Actual: False, Predicted: True
# Index: 391, Actual: False, Predicted: True
# Index: 392, Actual: False, Predicted: True
# Index: 398, Actual: False, Predicted: True
# Index: 403, Actual: False, Predicted: True
# Index: 405, Actual: False, Predicted: True
# Index: 412, Actual: True, Predicted: False
# Index: 441, Actual: False, Predicted: True
# Index: 450, Actual: True, Predicted: False
# Index: 453, Actual: False, Predicted: True
# Index: 456, Actual: False, Predicted: True
# Index: 458, Actual: False, Predicted: True
# Index: 462, Actual: True, Predicted: False
# Index: 466, Actual: False, Predicted: True
# Index: 468, Actual: False, Predicted: True
# Index: 474, Actual: False, Predicted: True
# Index: 478, Actual: False, Predicted: True
# Index: 480, Actual: True, Predicted: False
# Index: 487, Actual: False, Predicted: True
# Index: 493, Actual: False, Predicted: True
# Index: 494, Actual: False, Predicted: True
# Index: 495, Actual: False, Predicted: True
# Index: 499, Actual: False, Predicted: True
# Index: 500, Actual: False, Predicted: True
# Index: 502, Actual: False, Predicted: True
# Index: 505, Actual: False, Predicted: True
# Index: 517, Actual: False, Predicted: True
# Index: 518, Actual: False, Predicted: True
# Index: 520, Actual: False, Predicted: True
# Index: 538, Actual: False, Predicted: True
# Index: 545, Actual: False, Predicted: True
# Index: 555, Actual: False, Predicted: True
# Index: 570, Actual: False, Predicted: True
# Index: 583, Actual: False, Predicted: True
# Index: 594, Actual: False, Predicted: True
# Index: 597, Actual: False, Predicted: True
# Index: 604, Actual: True, Predicted: False
# Index: 608, Actual: True, Predicted: False
# Index: 611, Actual: False, Predicted: True
# Index: 619, Actual: False, Predicted: True
# Index: 621, Actual: False, Predicted: True
# Index: 626, Actual: False, Predicted: True
# Index: 631, Actual: True, Predicted: False
# Index: 645, Actual: False, Predicted: True
# Index: 653, Actual: False, Predicted: True
# Index: 657, Actual: False, Predicted: True
# Index: 670, Actual: False, Predicted: True
# Index: 672, Actual: False, Predicted: True
# Index: 676, Actual: False, Predicted: True
# Index: 683, Actual: True, Predicted: False
# Index: 695, Actual: False, Predicted: True
# Index: 701, Actual: False, Predicted: True
# Index: 722, Actual: True, Predicted: False
# Index: 734, Actual: False, Predicted: True
# Index: 742, Actual: False, Predicted: True
# Index: 755, Actual: False, Predicted: True
# Index: 758, Actual: False, Predicted: True
# Index: 765, Actual: False, Predicted: True
# Index: 766, Actual: False, Predicted: True
# Index: 773, Actual: False, Predicted: True
# Index: 775, Actual: True, Predicted: False
# Index: 777, Actual: False, Predicted: True
# Index: 781, Actual: False, Predicted: True
# Index: 784, Actual: True, Predicted: False
# Index: 796, Actual: False, Predicted: True
# Index: 819, Actual: False, Predicted: True
# Index: 822, Actual: False, Predicted: True
# Index: 828, Actual: False, Predicted: True
# Index: 830, Actual: False, Predicted: True
# Index: 852, Actual: False, Predicted: True
# Index: 853, Actual: False, Predicted: True
# Index: 866, Actual: False, Predicted: True
# Index: 871, Actual: False, Predicted: True
# Index: 875, Actual: False, Predicted: True
# Index: 892, Actual: False, Predicted: True
# Index: 899, Actual: False, Predicted: True
# Index: 906, Actual: False, Predicted: True
# Index: 908, Actual: False, Predicted: True
# Index: 916, Actual: False, Predicted: True
# Index: 935, Actual: False, Predicted: True
# Index: 955, Actual: True, Predicted: False
# Index: 958, Actual: False, Predicted: True
# Index: 963, Actual: False, Predicted: True
# Index: 970, Actual: True, Predicted: False
# Index: 984, Actual: False, Predicted: True
# Index: 989, Actual: False, Predicted: True
# Index: 997, Actual: False, Predicted: True
# Index: 998, Actual: False, Predicted: True
# Index: 1021, Actual: False, Predicted: True
# Index: 1028, Actual: False, Predicted: True
# Index: 1029, Actual: False, Predicted: True
# Index: 1032, Actual: True, Predicted: False
# Index: 1040, Actual: False, Predicted: True
# Index: 1041, Actual: False, Predicted: True
# Index: 1042, Actual: False, Predicted: True
# Index: 1044, Actual: False, Predicted: True
# Index: 1057, Actual: False, Predicted: True
# Index: 1062, Actual: False, Predicted: True
# Index: 1063, Actual: False, Predicted: True
# Index: 1067, Actual: False, Predicted: True
# Index: 1082, Actual: False, Predicted: True
# Index: 1089, Actual: False, Predicted: True
# Index: 1091, Actual: False, Predicted: True
# Index: 1093, Actual: True, Predicted: False
# Index: 1094, Actual: False, Predicted: True
# Index: 1095, Actual: False, Predicted: True
# Index: 1098, Actual: False, Predicted: True
# Index: 1100, Actual: True, Predicted: False
# Index: 1104, Actual: False, Predicted: True
# Index: 1108, Actual: False, Predicted: True
# Index: 1109, Actual: False, Predicted: True
# Index: 1110, Actual: True, Predicted: False
# Index: 1122, Actual: False, Predicted: True
# Index: 1123, Actual: False, Predicted: True
# Index: 1130, Actual: False, Predicted: True
# Index: 1133, Actual: False, Predicted: True
# Index: 1142, Actual: False, Predicted: True
# Index: 1165, Actual: True, Predicted: False
# Index: 1166, Actual: True, Predicted: False
# Index: 1174, Actual: False, Predicted: True
# Index: 1179, Actual: False, Predicted: True
# Index: 1183, Actual: True, Predicted: False
# Index: 1185, Actual: False, Predicted: True
# Index: 1186, Actual: False, Predicted: True
# Index: 1201, Actual: False, Predicted: True
# Index: 1205, Actual: False, Predicted: True
# Index: 1217, Actual: False, Predicted: True
# Index: 1218, Actual: True, Predicted: False
# Index: 1227, Actual: False, Predicted: True
# Index: 1231, Actual: False, Predicted: True
# Index: 1232, Actual: False, Predicted: True
# Index: 1233, Actual: False, Predicted: True
# Index: 1245, Actual: False, Predicted: True
# Index: 1259, Actual: False, Predicted: True
# Index: 1260, Actual: False, Predicted: True
# Index: 1265, Actual: False, Predicted: True
# Index: 1275, Actual: False, Predicted: True
# Index: 1276, Actual: True, Predicted: False
# Index: 1278, Actual: False, Predicted: True
# Index: 1289, Actual: False, Predicted: True
# Index: 1290, Actual: False, Predicted: True
# Index: 1291, Actual: False, Predicted: True
# Index: 1294, Actual: False, Predicted: True
# Index: 1301, Actual: False, Predicted: True
# Index: 1304, Actual: False, Predicted: True
# Index: 1313, Actual: False, Predicted: True
# Index: 1317, Actual: False, Predicted: True
# Index: 1322, Actual: False, Predicted: True
# Index: 1323, Actual: False, Predicted: True
# Index: 1333, Actual: False, Predicted: True
# Index: 1334, Actual: False, Predicted: True
# Index: 1335, Actual: False, Predicted: True
# Index: 1345, Actual: False, Predicted: True
# Index: 1350, Actual: False, Predicted: True
# Index: 1352, Actual: False, Predicted: True
# Index: 1359, Actual: False, Predicted: True
# ...
# Index: 1867, Actual: True, Predicted: False
# Index: 1868, Actual: True, Predicted: False
# Index: 1877, Actual: True, Predicted: False
# Index: 1878, Actual: True, Predicted: False
# Index: 1881, Actual: True, Predicted: False
# Index: 1883, Actual: True, Predicted: False
# Index: 1887, Actual: True, Predicted: False
# Index: 1889, Actual: True, Predicted: False
# Index: 1892, Actual: True, Predicted: False
# Index: 1895, Actual: True, Predicted: False
# Index: 1896, Actual: True, Predicted: False
# Index: 1897, Actual: True, Predicted: False
# Index: 1898, Actual: True, Predicted: False
# Index: 1903, Actual: True, Predicted: False
# Index: 1908, Actual: True, Predicted: False
# Index: 1909, Actual: True, Predicted: False
# Index: 1914, Actual: True, Predicted: False
# Index: 1917, Actual: True, Predicted: False
# Index: 1919, Actual: True, Predicted: False
# Index: 1923, Actual: True, Predicted: False
# Index: 1925, Actual: True, Predicted: False
# Index: 1926, Actual: True, Predicted: False
# Index: 1928, Actual: True, Predicted: False
# Index: 1931, Actual: True, Predicted: False
# Index: 1935, Actual: True, Predicted: False
# Index: 1936, Actual: True, Predicted: False
# Index: 1938, Actual: True, Predicted: False
# Index: 1942, Actual: True, Predicted: False
# Index: 1943, Actual: True, Predicted: False
# Index: 1945, Actual: False, Predicted: True
# Index: 1946, Actual: True, Predicted: False
# Index: 1948, Actual: True, Predicted: False
# Index: 1952, Actual: False, Predicted: True
# Index: 1954, Actual: True, Predicted: False
# Index: 1956, Actual: True, Predicted: False
# Index: 1964, Actual: True, Predicted: False
# Index: 1966, Actual: True, Predicted: False
# Index: 1969, Actual: False, Predicted: True
# Index: 1972, Actual: True, Predicted: False
# Index: 1974, Actual: True, Predicted: False
# Index: 1976, Actual: True, Predicted: False
# Index: 1977, Actual: True, Predicted: False
# Index: 1982, Actual: True, Predicted: False
# Index: 1987, Actual: True, Predicted: False
# Index: 1989, Actual: True, Predicted: False
# Index: 1990, Actual: True, Predicted: False
# Index: 1991, Actual: True, Predicted: False
# Index: 1992, Actual: True, Predicted: False
# Index: 1998, Actual: True, Predicted: False
# Index: 1999, Actual: True, Predicted: False
# Index: 2000, Actual: True, Predicted: False
# Index: 2004, Actual: True, Predicted: False
# Index: 2005, Actual: True, Predicted: False
# Index: 2007, Actual: True, Predicted: False
# Index: 2011, Actual: True, Predicted: False
# Index: 2013, Actual: True, Predicted: False
# Index: 2015, Actual: True, Predicted: False
# Index: 2017, Actual: True, Predicted: False
# Index: 2018, Actual: True, Predicted: False
# Index: 2026, Actual: True, Predicted: False
# Index: 2028, Actual: True, Predicted: False
# Index: 2029, Actual: True, Predicted: False
# Index: 2030, Actual: False, Predicted: True
# Index: 2034, Actual: True, Predicted: False
# Index: 2036, Actual: True, Predicted: False
# Index: 2038, Actual: True, Predicted: False
# Index: 2041, Actual: True, Predicted: False
# Index: 2046, Actual: True, Predicted: False
# Index: 2049, Actual: True, Predicted: False
# Index: 2051, Actual: True, Predicted: False
# Index: 2052, Actual: True, Predicted: False
# Index: 2059, Actual: True, Predicted: False
# Index: 2061, Actual: True, Predicted: False
# Index: 2062, Actual: True, Predicted: False
# Index: 2064, Actual: True, Predicted: False
# Index: 2065, Actual: True, Predicted: False
# Index: 2068, Actual: True, Predicted: False
# Index: 2069, Actual: True, Predicted: False
# Index: 2071, Actual: True, Predicted: False
# Index: 2072, Actual: True, Predicted: False
# Index: 2073, Actual: True, Predicted: False
# Index: 2077, Actual: True, Predicted: False
# Index: 2083, Actual: True, Predicted: False
# Index: 2091, Actual: True, Predicted: False
# Index: 2093, Actual: True, Predicted: False
# Index: 2098, Actual: True, Predicted: False
# Index: 2100, Actual: True, Predicted: False
# Index: 2101, Actual: True, Predicted: False
# Index: 2104, Actual: True, Predicted: False
# Index: 2107, Actual: True, Predicted: False
# Index: 2109, Actual: True, Predicted: False
# Index: 2114, Actual: True, Predicted: False
# Index: 2115, Actual: True, Predicted: False
# Index: 2122, Actual: True, Predicted: False
# Index: 2127, Actual: True, Predicted: False
# Index: 2131, Actual: False, Predicted: True
# Index: 2133, Actual: True, Predicted: False
# Index: 2134, Actual: True, Predicted: False
# Index: 2136, Actual: True, Predicted: False
# Index: 2137, Actual: True, Predicted: False
# Index: 2138, Actual: True, Predicted: False
# Index: 2143, Actual: True, Predicted: False
# Index: 2146, Actual: True, Predicted: False
# Index: 2151, Actual: True, Predicted: False
# Index: 2153, Actual: True, Predicted: False
# Index: 2159, Actual: True, Predicted: False
# Index: 2167, Actual: True, Predicted: False
# Index: 2169, Actual: True, Predicted: False
# Index: 2175, Actual: True, Predicted: False
# Index: 2182, Actual: True, Predicted: False
# Index: 2185, Actual: True, Predicted: False
# Index: 2188, Actual: True, Predicted: False
# Index: 2191, Actual: False, Predicted: True
# Index: 2193, Actual: True, Predicted: False
# Index: 2196, Actual: True, Predicted: False
# Index: 2197, Actual: True, Predicted: False
# Index: 2198, Actual: True, Predicted: False
# Index: 2201, Actual: True, Predicted: False
# Index: 2203, Actual: True, Predicted: False
# Index: 2205, Actual: True, Predicted: False
# Index: 2209, Actual: True, Predicted: False
# Index: 2213, Actual: True, Predicted: False
# Index: 2214, Actual: True, Predicted: False
# Index: 2215, Actual: True, Predicted: False
# Index: 2216, Actual: True, Predicted: False
# Index: 2218, Actual: True, Predicted: False
# Index: 2219, Actual: True, Predicted: False
# Index: 2221, Actual: True, Predicted: False
# Index: 2243, Actual: True, Predicted: False
# Index: 2245, Actual: True, Predicted: False
# Index: 2246, Actual: True, Predicted: False
# Index: 2250, Actual: True, Predicted: False
# Index: 2252, Actual: False, Predicted: True
# Index: 2260, Actual: True, Predicted: False
# Index: 2264, Actual: True, Predicted: False
# Index: 2266, Actual: True, Predicted: False
# Index: 2269, Actual: True, Predicted: False
# Index: 2271, Actual: True, Predicted: False
# Index: 2275, Actual: True, Predicted: False
# Index: 2281, Actual: True, Predicted: False
# Index: 2285, Actual: True, Predicted: False
# Index: 2286, Actual: True, Predicted: False
# Index: 2289, Actual: True, Predicted: False
# Index: 2295, Actual: True, Predicted: False
# Index: 2300, Actual: True, Predicted: False
# Index: 2306, Actual: True, Predicted: False
# Index: 2314, Actual: True, Predicted: False
# Index: 2316, Actual: True, Predicted: False
# Index: 2318, Actual: True, Predicted: False
# Index: 2319, Actual: True, Predicted: False
# Index: 2320, Actual: True, Predicted: False
# Index: 2322, Actual: True, Predicted: False
# Index: 2323, Actual: True, Predicted: False
# Index: 2325, Actual: True, Predicted: False
# Index: 2328, Actual: True, Predicted: False
# Index: 2329, Actual: True, Predicted: False
# Index: 2340, Actual: True, Predicted: False
# Index: 2345, Actual: True, Predicted: False
# Index: 2349, Actual: True, Predicted: False
# Index: 2350, Actual: False, Predicted: True
# Index: 2353, Actual: True, Predicted: False
# Index: 2358, Actual: True, Predicted: False
# Index: 2359, Actual: True, Predicted: False
# Index: 2363, Actual: True, Predicted: False
# Index: 2367, Actual: True, Predicted: False
# Index: 2375, Actual: True, Predicted: False
# Index: 2376, Actual: True, Predicted: False
# Index: 2378, Actual: True, Predicted: False
# Index: 2379, Actual: True, Predicted: False
# Index: 2380, Actual: False, Predicted: True
# Index: 2381, Actual: True, Predicted: False
# Index: 2382, Actual: True, Predicted: False
# Index: 2383, Actual: True, Predicted: False
# Index: 2386, Actual: True, Predicted: False
# Index: 2389, Actual: True, Predicted: False
# Index: 2395, Actual: True, Predicted: False
# Index: 2401, Actual: True, Predicted: False
# Index: 2409, Actual: True, Predicted: False
# Index: 2417, Actual: True, Predicted: False
# Index: 2418, Actual: False, Predicted: True
# Index: 2419, Actual: True, Predicted: False
# Index: 2421, Actual: False, Predicted: True
# Index: 2424, Actual: True, Predicted: False
# Index: 2426, Actual: True, Predicted: False
# Index: 2431, Actual: True, Predicted: False
# Index: 2434, Actual: True, Predicted: False
# Index: 2436, Actual: True, Predicted: False
# Index: 2437, Actual: True, Predicted: False
# Index: 2438, Actual: True, Predicted: False
# Index: 2441, Actual: True, Predicted: False
# Index: 2443, Actual: True, Predicted: False
# Index: 2447, Actual: True, Predicted: False
# Index: 2450, Actual: True, Predicted: False
# Index: 2453, Actual: True, Predicted: False
# Index: 2454, Actual: True, Predicted: False
# Index: 2456, Actual: True, Predicted: False
# Index: 2462, Actual: True, Predicted: False
# Index: 2463, Actual: True, Predicted: False
# Index: 2464, Actual: True, Predicted: False
# Index: 2466, Actual: True, Predicted: False
# Index: 2470, Actual: False, Predicted: True
# Index: 2472, Actual: True, Predicted: False
# Index: 2474, Actual: True, Predicted: False
# Index: 2477, Actual: False, Predicted: True
# Index: 2484, Actual: True, Predicted: False
# Index: 2485, Actual: True, Predicted: False
# Index: 2498, Actual: True, Predicted: False
# Index: 2503, Actual: True, Predicted: False
# Index: 2513, Actual: True, Predicted: False
# Index: 2516, Actual: True, Predicted: False
# Index: 2520, Actual: True, Predicted: False
# Index: 2523, Actual: True, Predicted: False
# Index: 2533, Actual: True, Predicted: False
# Index: 2537, Actual: True, Predicted: False
# Index: 2550, Actual: True, Predicted: False
# Index: 2551, Actual: True, Predicted: False
# Index: 2553, Actual: True, Predicted: False
# Index: 2555, Actual: True, Predicted: False
# Index: 2558, Actual: True, Predicted: False
# Index: 2559, Actual: True, Predicted: False
# Index: 2561, Actual: True, Predicted: False
# Index: 2563, Actual: True, Predicted: False
# Index: 2567, Actual: True, Predicted: False
# Index: 2571, Actual: True, Predicted: False
# Index: 2572, Actual: True, Predicted: False
# Index: 2576, Actual: False, Predicted: True
# Index: 2581, Actual: True, Predicted: False
# Index: 2582, Actual: True, Predicted: False
# Index: 2584, Actual: True, Predicted: False
# Index: 2585, Actual: True, Predicted: False
# Index: 2588, Actual: True, Predicted: False
# Index: 2591, Actual: True, Predicted: False
# Index: 2592, Actual: True, Predicted: False
# Index: 2596, Actual: True, Predicted: False
# Index: 2602, Actual: True, Predicted: False
# Index: 2605, Actual: True, Predicted: False
# Index: 2606, Actual: True, Predicted: False
# Index: 2611, Actual: True, Predicted: False
# Index: 2612, Actual: True, Predicted: False
# Index: 2614, Actual: True, Predicted: False
# Index: 2619, Actual: True, Predicted: False
# Index: 2620, Actual: True, Predicted: False
# Index: 2622, Actual: True, Predicted: False
# Index: 2624, Actual: True, Predicted: False
# Index: 2629, Actual: True, Predicted: False
# Index: 2630, Actual: True, Predicted: False
# Index: 2632, Actual: True, Predicted: False
# Index: 2633, Actual: True, Predicted: False
# Index: 2634, Actual: True, Predicted: False
# Index: 2636, Actual: False, Predicted: True
# Index: 2638, Actual: True, Predicted: False
# Index: 2641, Actual: True, Predicted: False
# Index: 2643, Actual: True, Predicted: False
# Index: 2644, Actual: True, Predicted: False
# Index: 2648, Actual: True, Predicted: False
# Index: 2652, Actual: True, Predicted: False
# Index: 2661, Actual: True, Predicted: False
# Index: 2663, Actual: True, Predicted: False
# Index: 2667, Actual: True, Predicted: False
# Index: 2672, Actual: True, Predicted: False
# Index: 2681, Actual: True, Predicted: False
# Index: 2683, Actual: True, Predicted: False
# Index: 2685, Actual: True, Predicted: False
# Index: 2686, Actual: True, Predicted: False
# Index: 2699, Actual: True, Predicted: False
# Index: 2701, Actual: True, Predicted: False
# Index: 2703, Actual: True, Predicted: False
# Index: 2709, Actual: True, Predicted: False
# Index: 2713, Actual: True, Predicted: False
# Index: 2716, Actual: True, Predicted: False
# Index: 2717, Actual: True, Predicted: False
# Index: 2719, Actual: True, Predicted: False
# Index: 2720, Actual: True, Predicted: False
# Index: 2721, Actual: True, Predicted: False
# Index: 2722, Actual: True, Predicted: False
# Index: 2725, Actual: True, Predicted: False
# Index: 2728, Actual: True, Predicted: False
# Index: 2734, Actual: True, Predicted: False
# Index: 2735, Actual: True, Predicted: False
# Index: 2737, Actual: True, Predicted: False
# Index: 2740, Actual: True, Predicted: False
# Index: 2744, Actual: True, Predicted: False
# Index: 2746, Actual: True, Predicted: False
# Index: 2747, Actual: True, Predicted: False
# Index: 2748, Actual: True, Predicted: False
# Index: 2749, Actual: True, Predicted: False
# Index: 2750, Actual: True, Predicted: False
# Index: 2757, Actual: True, Predicted: False
# Index: 2762, Actual: True, Predicted: False
# Index: 2764, Actual: True, Predicted: False
# Index: 2765, Actual: True, Predicted: False
# Index: 2770, Actual: True, Predicted: False
# Index: 2773, Actual: True, Predicted: False
# Index: 2775, Actual: True, Predicted: False
# Index: 2776, Actual: True, Predicted: False
# Index: 2777, Actual: True, Predicted: False
# Index: 2779, Actual: True, Predicted: False
# Index: 2781, Actual: True, Predicted: False
# Index: 2784, Actual: True, Predicted: False
# Index: 2785, Actual: False, Predicted: True
# Index: 2787, Actual: True, Predicted: False
# Index: 2788, Actual: True, Predicted: False
# Index: 2795, Actual: True, Predicted: False
# Index: 2805, Actual: True, Predicted: False
# Index: 2809, Actual: True, Predicted: False
# Index: 2811, Actual: True, Predicted: False
# Index: 2812, Actual: True, Predicted: False
# Index: 2813, Actual: True, Predicted: False
# Index: 2817, Actual: True, Predicted: False
# Index: 2818, Actual: True, Predicted: False
# Index: 2828, Actual: False, Predicted: True
# Index: 2831, Actual: True, Predicted: False
# Index: 2833, Actual: True, Predicted: False
# Index: 2834, Actual: True, Predicted: False
# Index: 2835, Actual: True, Predicted: False
# Index: 2837, Actual: True, Predicted: False
# Index: 2843, Actual: True, Predicted: False
# Index: 2848, Actual: True, Predicted: False
# Index: 2850, Actual: True, Predicted: False
# Index: 2852, Actual: True, Predicted: False
# Index: 2853, Actual: True, Predicted: False
# Index: 2863, Actual: True, Predicted: False
# Index: 2868, Actual: True, Predicted: False
# Index: 2869, Actual: True, Predicted: False
# Index: 2870, Actual: True, Predicted: False
# Index: 2876, Actual: True, Predicted: False
# Index: 2880, Actual: True, Predicted: False
# Index: 2884, Actual: True, Predicted: False
# Index: 2885, Actual: True, Predicted: False
# Index: 2888, Actual: True, Predicted: False
# Index: 2894, Actual: True, Predicted: False
# Index: 2901, Actual: True, Predicted: False
# Index: 2903, Actual: True, Predicted: False
# Index: 2904, Actual: False, Predicted: True
# Index: 2905, Actual: True, Predicted: False
# Index: 2907, Actual: True, Predicted: False
# Index: 2911, Actual: True, Predicted: False
# Index: 2915, Actual: True, Predicted: False
# Index: 2916, Actual: True, Predicted: False
# Index: 2917, Actual: True, Predicted: False
# Index: 2922, Actual: True, Predicted: False
# Index: 2925, Actual: True, Predicted: False
# Index: 2928, Actual: True, Predicted: False
# Index: 2929, Actual: True, Predicted: False
# Index: 2930, Actual: True, Predicted: False
# Index: 2931, Actual: True, Predicted: False
# Index: 2932, Actual: True, Predicted: False
# Index: 2933, Actual: True, Predicted: False
# Index: 2936, Actual: True, Predicted: False
# Index: 2949, Actual: True, Predicted: False
# Index: 2950, Actual: True, Predicted: False
# Index: 2951, Actual: True, Predicted: False
# Index: 2952, Actual: True, Predicted: False
# Index: 2954, Actual: True, Predicted: False
# Index: 2955, Actual: True, Predicted: False
# Index: 2957, Actual: True, Predicted: False
# Index: 2960, Actual: False, Predicted: True
# Index: 2961, Actual: True, Predicted: False
# Index: 2963, Actual: True, Predicted: False
# Index: 2965, Actual: False, Predicted: True
# Index: 2969, Actual: True, Predicted: False
# Index: 2970, Actual: True, Predicted: False
# Index: 2974, Actual: True, Predicted: False
